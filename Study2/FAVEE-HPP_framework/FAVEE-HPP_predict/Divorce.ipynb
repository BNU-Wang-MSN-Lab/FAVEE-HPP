# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('India','Chile')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/divorce'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.84068 -0.74276 -0.05779  0.55411  2.49921
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.146e-16  7.998e-02     0.0        1
# scale(x)     3.693e-01  8.028e-02     4.6 9.67e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9328 on 134 degrees of freedom
# Multiple R-squared:  0.1364,	Adjusted R-squared:  0.1299
# F-statistic: 21.16 on 1 and 134 DF,  p-value: 9.673e-06
#
# [1] "fstats: 21.1606874389309"
# [1] "r2stats: 0.13637918075904"
# [1] 10000
# [1] "permf_pvals 0.0231"
#   full_rdm
# 1   0.0231
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.89060 -0.72432 -0.00994  0.52460  2.40731
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.998e-17  8.121e-02   0.000        1
# scale(x)     3.312e-01  8.151e-02   4.063 8.19e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9471 on 134 degrees of freedom
# Multiple R-squared:  0.1097,	Adjusted R-squared:  0.1031
# F-statistic: 16.51 on 1 and 134 DF,  p-value: 8.191e-05
#
# [1] "fstats: 16.5119509414938"
# [1] "r2stats: 0.109705248242462"
# [1] 10000
# [1] "permf_pvals 0.033"
#   favee_rdm
# 1    0.0328
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.09724 -0.50211  0.04729  0.51975  2.10305
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -4.372e-17  7.568e-02   0.000   1.0000
# scale(x)formality_rdm  -2.848e-01  1.104e-01  -2.579   0.0110 *
# scale(x)activeness_rdm -1.673e-01  1.224e-01  -1.367   0.1741
# scale(x)valence_rdm     8.933e-01  1.750e-01   5.105 1.15e-06 ***
# scale(x)exchange_rdm    1.667e-01  9.003e-02   1.852   0.0663 .
# scale(x)equality_rdm   -2.364e-01  1.576e-01  -1.500   0.1361
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8826 on 130 degrees of freedom
# Multiple R-squared:  0.2499,	Adjusted R-squared:  0.221
# F-statistic: 8.661 on 5 and 130 DF,  p-value: 4.148e-07
#
# [1] "fstats: 8.66068834492996"
# [1] "r2stats: 0.249870639000071"
# [1] 10000
# [1] "permf_pvals 0.0275"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1        0.9416         0.7766      0.0037       0.1807       0.8137
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.57016 -0.81686 -0.09364  0.57784  2.59675
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.019e-16  8.526e-02   0.000    1.000
# scale(x)     1.365e-01  8.558e-02   1.595    0.113
#
# Residual standard error: 0.9943 on 134 degrees of freedom
# Multiple R-squared:  0.01862,	Adjusted R-squared:  0.0113
# F-statistic: 2.543 on 1 and 134 DF,  p-value: 0.1131
#
# [1] "fstats: 2.54296150401283"
# [1] "r2stats: 0.0186238929931082"
# [1] 10000
# [1] "permf_pvals 0.3977"
#   formality_rdm
# 1        0.1933
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.52001 -0.72662 -0.07321  0.51442  2.55652
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.088e-16  8.365e-02   0.000  1.00000
# scale(x)     2.354e-01  8.396e-02   2.803  0.00581 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9755 on 134 degrees of freedom
# Multiple R-squared:  0.0554,	Adjusted R-squared:  0.04835
# F-statistic: 7.859 on 1 and 134 DF,  p-value: 0.005808
#
# [1] "fstats: 7.85921442361658"
# [1] "r2stats: 0.0554015081469969"
# [1] 10000
# [1] "permf_pvals 0.0988"
#   activeness_rdm
# 1         0.0653
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.85746 -0.68125 -0.04166  0.48470  2.48176
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.134e-17  7.806e-02   0.000        1
# scale(x)     4.213e-01  7.835e-02   5.377 3.27e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9103 on 134 degrees of freedom
# Multiple R-squared:  0.1775,	Adjusted R-squared:  0.1713
# F-statistic: 28.91 on 1 and 134 DF,  p-value: 3.273e-07
#
# [1] "fstats: 28.9095241554471"
# [1] "r2stats: 0.177457544642153"
# [1] 10000
# [1] "permf_pvals 0.014"
#   valence_rdm
# 1       0.014
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.44491 -0.76176 -0.08671  0.53664  2.80740
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.434e-16  8.527e-02   0.000    1.000
# scale(x)     1.356e-01  8.559e-02   1.585    0.115
#
# Residual standard error: 0.9945 on 134 degrees of freedom
# Multiple R-squared:  0.01839,	Adjusted R-squared:  0.01107
# F-statistic: 2.511 on 1 and 134 DF,  p-value: 0.1154
#
# [1] "fstats: 2.51082219754925"
# [1] "r2stats: 0.0183928435645619"
# [1] 10000
# [1] "permf_pvals 0.3914"
#   exchange_rdm
# 1       0.1819
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6968 -0.7559 -0.0085  0.5053  2.4886
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.369e-17  8.212e-02   0.000 1.000000
# scale(x)     2.996e-01  8.242e-02   3.635 0.000395 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9576 on 134 degrees of freedom
# Multiple R-squared:  0.08974,	Adjusted R-squared:  0.08295
# F-statistic: 13.21 on 1 and 134 DF,  p-value: 0.0003955
#
# [1] "fstats: 13.2113798684305"
# [1] "r2stats: 0.0897442839014083"
# [1] 10000
# [1] "permf_pvals 0.0441"
#   equality_rdm
# 1       0.0425
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4362 -0.8151 -0.1213  0.5695  2.7372
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.347e-16  8.563e-02   0.000    1.000
# scale(x)     1.003e-01  8.595e-02   1.167    0.245
#
# Residual standard error: 0.9987 on 134 degrees of freedom
# Multiple R-squared:  0.01005,	Adjusted R-squared:  0.002666
# F-statistic: 1.361 on 1 and 134 DF,  p-value: 0.2455
#
# [1] "fstats: 1.36081630201199"
# [1] "r2stats: 0.0100532512967105"
# [1] 10000
# [1] "permf_pvals 0.4637"
#   hpp_rdm
# 1  0.2331
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4605 -0.7619 -0.1085  0.5264  2.6514
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -9.321e-17  8.593e-02   0.000    1.000
# scale(x)hostile_rdm  3.357e-02  1.058e-01   0.317    0.752
# scale(x)private_rdm -1.007e-01  1.138e-01  -0.885    0.378
# scale(x)public_rdm   1.549e-01  1.143e-01   1.355    0.178
#
# Residual standard error: 1.002 on 132 degrees of freedom
# Multiple R-squared:  0.01818,	Adjusted R-squared:  -0.004136
# F-statistic: 0.8146 on 3 and 132 DF,  p-value: 0.4879
#
# [1] "fstats: 0.814648469845592"
# [1] "r2stats: 0.0181781738262154"
# [1] 10000
# [1] "permf_pvals 0.7164"
#   hostile_rdm private_rdm public_rdm
# 1      0.4467      0.7467     0.1955
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.3588 -0.8098 -0.1668  0.5872  2.7637
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.432e-16  8.590e-02   0.000     1.00
# scale(x)     6.249e-02  8.622e-02   0.725     0.47
#
# Residual standard error: 1.002 on 134 degrees of freedom
# Multiple R-squared:  0.003905,	Adjusted R-squared:  -0.003529
# F-statistic: 0.5253 on 1 and 134 DF,  p-value: 0.4698
#
# [1] "fstats: 0.525320098843261"
# [1] "r2stats: 0.00390499051373585"
# [1] 10000
# [1] "permf_pvals 0.4681"
#   hostile_rdm
# 1      0.2181
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.3804 -0.7910 -0.1880  0.6225  2.7431
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.364e-16  8.606e-02   0.000    1.000
# scale(x)     1.113e-02  8.638e-02   0.129    0.898
#
# Residual standard error: 1.004 on 134 degrees of freedom
# Multiple R-squared:  0.000124,	Adjusted R-squared:  -0.007338
# F-statistic: 0.01661 on 1 and 134 DF,  p-value: 0.8976
#
# [1] "fstats: 0.0166145264857059"
# [1] "r2stats: 0.000123973632257532"
# [1] 10000
# [1] "permf_pvals 0.93"
#   private_rdm
# 1      0.4404
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4277 -0.8035 -0.1053  0.5757  2.7150
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.071e-16  8.554e-02   0.000    1.000
# scale(x)     1.110e-01  8.585e-02   1.293    0.198
#
# Residual standard error: 0.9975 on 134 degrees of freedom
# Multiple R-squared:  0.01233,	Adjusted R-squared:  0.004961
# F-statistic: 1.673 on 1 and 134 DF,  p-value: 0.1981
#
# [1] "fstats: 1.67304008718314"
# [1] "r2stats: 0.0123314115030374"
# [1] 10000
# [1] "permf_pvals 0.4603"
#   public_rdm
# 1     0.2281
# [1] "###############################################################"

# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('Qatar')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/social_support'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6983 -0.4298 -0.0098  0.3450  1.8411
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 5.648e-18  5.907e-02    0.00        1
# scale(x)    6.854e-01  5.926e-02   11.57   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7306 on 151 degrees of freedom
# Multiple R-squared:  0.4697,	Adjusted R-squared:  0.4662
# F-statistic: 133.8 on 1 and 151 DF,  p-value: < 2.2e-16
#
# [1] "fstats: 133.762619218443"
# [1] "r2stats: 0.469733771888905"
# [1] 10000
# [1] "permf_pvals 0.0021"
#   full_rdm
# 1   0.0021
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6737 -0.5140 -0.0585  0.4361  2.1558
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.111e-16  6.425e-02    0.00        1
# scale(x)    6.104e-01  6.446e-02    9.47   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7947 on 151 degrees of freedom
# Multiple R-squared:  0.3726,	Adjusted R-squared:  0.3684
# F-statistic: 89.67 on 1 and 151 DF,  p-value: < 2.2e-16
#
# [1] "fstats: 89.673020651493"
# [1] "r2stats: 0.372592741840159"
# [1] 10000
# [1] "permf_pvals 0.0034"
#   favee_rdm
# 1    0.0034
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.66383 -0.51661  0.00481  0.49763  1.62718
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             1.726e-16  5.778e-02   0.000 1.000000
# scale(x)formality_rdm  -1.760e-01  7.508e-02  -2.344 0.020432 *
# scale(x)activeness_rdm -1.465e-01  9.112e-02  -1.607 0.110151
# scale(x)valence_rdm     2.969e-01  9.498e-02   3.126 0.002137 **
# scale(x)exchange_rdm    4.733e-01  6.824e-02   6.935 1.19e-10 ***
# scale(x)equality_rdm    3.337e-01  8.523e-02   3.915 0.000138 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7147 on 147 degrees of freedom
# Multiple R-squared:  0.506,	Adjusted R-squared:  0.4892
# F-statistic: 30.11 on 5 and 147 DF,  p-value: < 2.2e-16
#
# [1] "fstats: 30.113420005748"
# [1] "r2stats: 0.505993774225032"
# [1] 10000
# [1] "permf_pvals 0.0116"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1        0.7622         0.6779      0.1447       0.0435        0.102
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.3512 -0.6403 -0.2421  0.2910  2.8920
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.323e-17  7.771e-02   0.000 1.000000
# scale(x)     2.868e-01  7.796e-02   3.678 0.000326 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9612 on 151 degrees of freedom
# Multiple R-squared:  0.08224,	Adjusted R-squared:  0.07616
# F-statistic: 13.53 on 1 and 151 DF,  p-value: 0.0003258
#
# [1] "fstats: 13.5309262286674"
# [1] "r2stats: 0.0822394095676696"
# [1] 10000
# [1] "permf_pvals 0.1129"
#   formality_rdm
# 1        0.0957
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4344 -0.6351 -0.2144  0.4397  2.8842
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -3.636e-17  7.509e-02   0.000        1
# scale(x)     3.782e-01  7.533e-02   5.021 1.43e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9288 on 151 degrees of freedom
# Multiple R-squared:  0.143,	Adjusted R-squared:  0.1374
# F-statistic: 25.21 on 1 and 151 DF,  p-value: 1.434e-06
#
# [1] "fstats: 25.2060566383011"
# [1] "r2stats: 0.14304875280219"
# [1] 10000
# [1] "permf_pvals 0.0234"
#   activeness_rdm
# 1         0.0234
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5684 -0.5675 -0.1145  0.3905  2.3531
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.167e-16  7.124e-02    0.00        1
# scale(x)    4.781e-01  7.147e-02    6.69 4.09e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8812 on 151 degrees of freedom
# Multiple R-squared:  0.2286,	Adjusted R-squared:  0.2235
# F-statistic: 44.75 on 1 and 151 DF,  p-value: 4.09e-10
#
# [1] "fstats: 44.7537604611116"
# [1] "r2stats: 0.228622736828611"
# [1] 10000
# [1] "permf_pvals 0.0196"
#   valence_rdm
# 1      0.0196
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8672 -0.4773 -0.0655  0.4564  1.9403
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.184e-17  6.533e-02   0.000        1
# scale(x)     5.926e-01  6.555e-02   9.041 7.03e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8081 on 151 degrees of freedom
# Multiple R-squared:  0.3512,	Adjusted R-squared:  0.3469
# F-statistic: 81.74 on 1 and 151 DF,  p-value: 7.034e-16
#
# [1] "fstats: 81.7446915242611"
# [1] "r2stats: 0.351220433810582"
# [1] 10000
# [1] "permf_pvals 0.0059"
#   exchange_rdm
# 1       0.0059
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6376 -0.5112 -0.1127  0.3479  2.2186
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.064e-16  6.678e-02   0.000        1
# scale(x)    5.676e-01  6.700e-02   8.471 2.01e-14 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.826 on 151 degrees of freedom
# Multiple R-squared:  0.3222,	Adjusted R-squared:  0.3177
# F-statistic: 71.76 on 1 and 151 DF,  p-value: 2.006e-14
#
# [1] "fstats: 71.7643039756954"
# [1] "r2stats: 0.322153516945539"
# [1] 10000
# [1] "permf_pvals 0.0031"
#   equality_rdm
# 1       0.0031
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.46165 -0.67257 -0.05788  0.45094  2.10128
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.893e-17  6.582e-02   0.000        1
# scale(x)    5.843e-01  6.604e-02   8.848  2.2e-15 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8142 on 151 degrees of freedom
# Multiple R-squared:  0.3415,	Adjusted R-squared:  0.3371
# F-statistic: 78.29 on 1 and 151 DF,  p-value: 2.203e-15
#
# [1] "fstats: 78.2935430935702"
# [1] "r2stats: 0.341455507369521"
# [1] 10000
# [1] "permf_pvals 0.0029"
#   hpp_rdm
# 1  0.0029
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.76301 -0.53788 -0.03138  0.43822  1.82440
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -3.196e-16  5.880e-02   0.000    1.000
# scale(x)hostile_rdm -1.794e-01  7.807e-02  -2.298    0.023 *
# scale(x)private_rdm -4.409e-02  8.688e-02  -0.507    0.613
# scale(x)public_rdm   8.139e-01  8.624e-02   9.437   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7273 on 149 degrees of freedom
# Multiple R-squared:  0.4815,	Adjusted R-squared:  0.471
# F-statistic: 46.12 on 3 and 149 DF,  p-value: < 2.2e-16
#
# [1] "fstats: 46.1153912864254"
# [1] "r2stats: 0.481461687835208"
# [1] 10000
# [1] "permf_pvals 0.0012"
#   hostile_rdm private_rdm public_rdm
# 1      0.8751      0.5756          0
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4264 -0.7168 -0.2224  0.2763  2.8390
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.825e-17  7.784e-02   0.000 1.000000
# scale(x)    2.813e-01  7.809e-02   3.602 0.000428 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9628 on 151 degrees of freedom
# Multiple R-squared:  0.07913,	Adjusted R-squared:  0.07303
# F-statistic: 12.97 on 1 and 151 DF,  p-value: 0.0004278
#
# [1] "fstats: 12.9748404140685"
# [1] "r2stats: 0.0791270196165733"
# [1] 10000
# [1] "permf_pvals 0.0237"
#   hostile_rdm
# 1      0.0237
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4226 -0.6495 -0.2383  0.4694  2.6257
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.165e-17  7.390e-02   0.000        1
# scale(x)     4.123e-01  7.414e-02   5.561 1.19e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9141 on 151 degrees of freedom
# Multiple R-squared:   0.17,	Adjusted R-squared:  0.1645
# F-statistic: 30.92 on 1 and 151 DF,  p-value: 1.188e-07
#
# [1] "fstats: 30.9229488975168"
# [1] "r2stats: 0.169978274235961"
# [1] 10000
# [1] "permf_pvals 0.0104"
#   private_rdm
# 1      0.0104
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.68372 -0.53193 -0.00764  0.48715  1.85552
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.490e-16  5.978e-02    0.00        1
# scale(x)     6.759e-01  5.998e-02   11.27   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.7395 on 151 degrees of freedom
# Multiple R-squared:  0.4568,	Adjusted R-squared:  0.4532
# F-statistic:   127 on 1 and 151 DF,  p-value: < 2.2e-16
#
# [1] "fstats: 126.983596664278"
# [1] "r2stats: 0.456802481110554"
# [1] 10000
# [1] "permf_pvals 5e-04"
#   public_rdm
# 1      5e-04
# [1] "###############################################################"

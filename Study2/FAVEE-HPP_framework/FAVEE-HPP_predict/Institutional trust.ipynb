# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('CHN','Qatar')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/Institutional_trust'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.21761 -0.68471 -0.04703  0.60122  2.37605
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.019e-17  7.711e-02   0.000        1
# scale(x)    4.443e-01  7.739e-02   5.741 6.01e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8992 on 134 degrees of freedom
# Multiple R-squared:  0.1974,	Adjusted R-squared:  0.1914
# F-statistic: 32.96 on 1 and 134 DF,  p-value: 6.013e-08
#
# [1] "fstats: 32.9580145942948"
# [1] "r2stats: 0.197403009818859"
# [1] 10000
# [1] "permf_pvals 0.0194"
#   full_rdm
# 1   0.0194
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9719 -0.7008 -0.1274  0.5935  2.6660
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -8.077e-17  7.981e-02   0.000        1
# scale(x)     3.744e-01  8.010e-02   4.674  7.1e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9307 on 134 degrees of freedom
# Multiple R-squared:  0.1402,	Adjusted R-squared:  0.1338
# F-statistic: 21.85 on 1 and 134 DF,  p-value: 7.101e-06
#
# [1] "fstats: 21.8488240090546"
# [1] "r2stats: 0.140192421392831"
# [1] 10000
# [1] "permf_pvals 0.0354"
#   favee_rdm
# 1    0.0351
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9576 -0.6239 -0.1135  0.5816  2.4806
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -4.997e-17  7.491e-02   0.000 1.000000
# scale(x)formality_rdm  -1.439e-01  9.636e-02  -1.494 0.137630
# scale(x)activeness_rdm  1.163e-02  1.194e-01   0.097 0.922582
# scale(x)valence_rdm     4.419e-01  1.221e-01   3.619 0.000422 ***
# scale(x)exchange_rdm    1.965e-01  8.811e-02   2.230 0.027452 *
# scale(x)equality_rdm    5.332e-02  1.079e-01   0.494 0.622174
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8736 on 130 degrees of freedom
# Multiple R-squared:  0.265,	Adjusted R-squared:  0.2368
# F-statistic: 9.376 on 5 and 130 DF,  p-value: 1.195e-07
#
# [1] "fstats: 9.37610196330629"
# [1] "r2stats: 0.26504056249701"
# [1] 10000
# [1] "permf_pvals 0.0774"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1        0.7183         0.4712      0.0757       0.1755       0.4255
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5106 -0.7877 -0.1690  0.6802  2.8750
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 7.949e-17  8.412e-02   0.000   1.0000
# scale(x)    2.116e-01  8.443e-02   2.507   0.0134 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.981 on 134 degrees of freedom
# Multiple R-squared:  0.04479,	Adjusted R-squared:  0.03766
# F-statistic: 6.284 on 1 and 134 DF,  p-value: 0.01338
#
# [1] "fstats: 6.28376463940418"
# [1] "r2stats: 0.0447932421514096"
# [1] 10000
# [1] "permf_pvals 0.2278"
#   formality_rdm
# 1        0.1224
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7356 -0.7065 -0.1493  0.6353  2.7453
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 8.327e-17  7.979e-02    0.00        1
# scale(x)    3.748e-01  8.009e-02    4.68 6.94e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9306 on 134 degrees of freedom
# Multiple R-squared:  0.1405,	Adjusted R-squared:  0.1341
# F-statistic:  21.9 on 1 and 134 DF,  p-value: 6.941e-06
#
# [1] "fstats: 21.8997231052574"
# [1] "r2stats: 0.140473136635859"
# [1] 10000
# [1] "permf_pvals 0.0168"
#   activeness_rdm
# 1         0.0148
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8984 -0.5662 -0.1126  0.4909  2.5168
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.660e-17  7.581e-02   0.000        1
# scale(x)     4.734e-01  7.609e-02   6.222 5.85e-09 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8841 on 134 degrees of freedom
# Multiple R-squared:  0.2241,	Adjusted R-squared:  0.2184
# F-statistic: 38.71 on 1 and 134 DF,  p-value: 5.853e-09
#
# [1] "fstats: 38.7116159758157"
# [1] "r2stats: 0.224140199008018"
# [1] 10000
# [1] "permf_pvals 0.01"
#   valence_rdm
# 1        0.01
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6635 -0.7232 -0.1623  0.6023  2.7303
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.098e-16  8.160e-02   0.000 1.000000
# scale(x)    3.179e-01  8.191e-02   3.881 0.000163 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9517 on 134 degrees of freedom
# Multiple R-squared:  0.101,	Adjusted R-squared:  0.09433
# F-statistic: 15.06 on 1 and 134 DF,  p-value: 0.0001626
#
# [1] "fstats: 15.0605296270075"
# [1] "r2stats: 0.101036335136426"
# [1] 10000
# [1] "permf_pvals 0.058"
#   exchange_rdm
# 1       0.0526
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6124 -0.6418 -0.1675  0.5905  2.6196
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.273e-17  8.011e-02   0.000        1
# scale(x)     3.657e-01  8.040e-02   4.548  1.2e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9342 on 134 degrees of freedom
# Multiple R-squared:  0.1337,	Adjusted R-squared:  0.1272
# F-statistic: 20.68 on 1 and 134 DF,  p-value: 1.201e-05
#
# [1] "fstats: 20.6819896261382"
# [1] "r2stats: 0.133706514094666"
# [1] 10000
# [1] "permf_pvals 0.0356"
#   equality_rdm
# 1       0.0345
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7791 -0.8004 -0.1606  0.6806  3.0258
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.254e-17  8.322e-02   0.000  1.00000
# scale(x)     2.552e-01  8.353e-02   3.055  0.00271 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9705 on 134 degrees of freedom
# Multiple R-squared:  0.06513,	Adjusted R-squared:  0.05816
# F-statistic: 9.336 on 1 and 134 DF,  p-value: 0.002712
#
# [1] "fstats: 9.3356992841024"
# [1] "r2stats: 0.0651317105977788"
# [1] 10000
# [1] "permf_pvals 0.1172"
#   hpp_rdm
# 1  0.0819
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9927 -0.7331 -0.1443  0.5596  2.8376
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          2.578e-17  8.158e-02   0.000  1.00000
# scale(x)hostile_rdm -1.797e-01  1.080e-01  -1.663  0.09859 .
# scale(x)private_rdm  6.619e-02  1.190e-01   0.556  0.57905
# scale(x)public_rdm   3.731e-01  1.196e-01   3.120  0.00222 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9514 on 132 degrees of freedom
# Multiple R-squared:  0.115,	Adjusted R-squared:  0.09489
# F-statistic: 5.718 on 3 and 132 DF,  p-value: 0.001038
#
# [1] "fstats: 5.71782229783262"
# [1] "r2stats: 0.115005485630087"
# [1] 10000
# [1] "permf_pvals 0.0963"
#   hostile_rdm private_rdm public_rdm
# 1      0.8747      0.3268     0.0528
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.2720 -0.8381 -0.1808  0.7151  2.9840
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.226e-17  8.576e-02   0.000    1.000
# scale(x)    8.444e-02  8.608e-02   0.981    0.328
#
# Residual standard error: 1 on 134 degrees of freedom
# Multiple R-squared:  0.00713,	Adjusted R-squared:  -0.0002798
# F-statistic: 0.9622 on 1 and 134 DF,  p-value: 0.3284
#
# [1] "fstats: 0.962233755395363"
# [1] "r2stats: 0.00712965196722595"
# [1] 10000
# [1] "permf_pvals 0.4452"
#   hostile_rdm
# 1      0.2179
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7755 -0.7415 -0.1708  0.6107  3.0549
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.698e-17  8.404e-02   0.000   1.0000
# scale(x)    2.161e-01  8.435e-02   2.562   0.0115 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.98 on 134 degrees of freedom
# Multiple R-squared:  0.04668,	Adjusted R-squared:  0.03957
# F-statistic: 6.562 on 1 and 134 DF,  p-value: 0.01153
#
# [1] "fstats: 6.56153121231119"
# [1] "r2stats: 0.0466808461441724"
# [1] 10000
# [1] "permf_pvals 0.1333"
#   private_rdm
# 1      0.0828
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8806 -0.8010 -0.1296  0.6280  2.9166
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.087e-17  8.181e-02   0.000 1.000000
# scale(x)    3.106e-01  8.212e-02   3.782 0.000234 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9541 on 134 degrees of freedom
# Multiple R-squared:  0.09645,	Adjusted R-squared:  0.0897
# F-statistic:  14.3 on 1 and 134 DF,  p-value: 0.0002335
#
# [1] "fstats: 14.3031553479725"
# [1] "r2stats: 0.0964453879245667"
# [1] 10000
# [1] "permf_pvals 0.0732"
#   public_rdm
# 1       0.06
# [1] "###############################################################"

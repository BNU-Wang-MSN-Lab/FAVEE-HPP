# %% [markdown]
# # Clean data

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn import manifold, preprocessing
import warnings

# %% [markdown]
# ## Prepare raw data(responses)/key(dimension)/relationships

# %%
warnings.filterwarnings('ignore')
# Grab the qualtrics output
qual_output = [i for i in os.listdir('input_data/') if i.startswith('CHN_group')][0]

# Prep responses and key--raw data
raw = pd.read_csv(os.getcwd()+'/input_data/'+qual_output)
raw_reorg = raw.drop(axis='index',index=[0,1])
raw_reorg['subject'] = list(raw_reorg.index)
raw_reorg = raw_reorg.reset_index(drop=True)
raw_reorg['Duration (in seconds)'] = pd.to_numeric(raw_reorg['Duration (in seconds)'])

# Prep responses and key
key = pd.read_csv('input_data/qualtrics_question_key.csv')

responses = raw_reorg
responses['subject'] = list(raw_reorg.index)
responses = responses.loc[:, responses.columns.str.startswith('Q')]
responses = responses[responses.columns[1:-7]]

# Get total number of responses
print("Total number of responses from qualtrics - "+str(len(responses)))
# Out:
# Total number of responses from qualtrics - 54

# %%
# Prep relationships
filter_col = [col for col in raw if col.startswith('Q4.2')]
relationships = pd.read_csv('input_data/group_relationships_fix_label_sup.csv', index_col=0)
relationships = relationships.iloc[:,0].to_list()

# Prep dimensions
dimensions = key['dimension'].tolist()[1:-1]
items_to_remove = ["foil", "foil size"]
dimensions = [item for item in dimensions if item not in items_to_remove]

dimension_frames = {}
count = 1
for dim in dimensions:  # exclude foil and demographics
    filtered_cols = [col for col in raw_reorg if col.startswith('Q' + str(key['block'].iloc[count]) + '.2')]
    dimension_frames[dim] = pd.DataFrame(responses[filtered_cols])    
    count += 1
# Get total number of relationships and dimensions    
print("Total number of relationships - " + str(len(dimension_frames[dim].columns)))
print("Total number of dimensions - " + str(len(dimensions)))
# Out:
# Total number of relationships - 15
# Total number of dimensions - 33

# %% [markdown]
# ## time/foil/foil_size

# %%
time = pd.to_numeric(raw_reorg['Duration (in seconds)'], errors='coerce')
time[time > time.mean() + 3.5 * time.std()]
outliers_max = time.index[time == time.max()]
time = time[~time.index.isin(outliers_max)]
outliers = time[time < time.mean() - 1.5 * time.std()]
outliers
# Out:
# Series([], Name: Duration (in seconds), dtype: int64)

# %%
time = pd.to_numeric(raw_reorg['Duration (in seconds)'], errors='coerce')
print(time.max())
time_max_index = time.index[time == time.max()]
time = time[~time.index.isin(time_max_index)]
time = pd.DataFrame(time)

time['Random ID'] =raw_reorg['Random ID']
time = time.apply(pd.to_numeric)
time_melt = pd.melt(time, id_vars='Random ID')

outliers_time_list = list(time_max_index)
for col in time.columns[:-1]:
    outliers_time_list = outliers_time_list + list(time[time[col] < time[col].mean()-time[col].std()*1.5].index)
outliers_time_list = set(outliers_time_list)

outliers_time_list
# Out:
# 2141
# {49}

# %%
# Check foils to exclude people
foil_items = [x for x in raw.columns.tolist() if x.startswith('Q38.1')]
foil_items = raw[foil_items].iloc[0]
foil_items = [i.split(' - ', 1)[1] if ' - ' in i else i for i in foil_items]

filtered_cols = [col for col in raw_reorg if col.startswith('Q38.1')]
foils_size = pd.DataFrame(responses[filtered_cols])
foils_size.columns = foil_items
foils_size['Random ID'] =raw_reorg['Random ID']
foils_size = foils_size.apply(pd.to_numeric)

foils_size_melt = pd.melt(foils_size, id_vars='Random ID')

# %%
# Check for values above means for unexpected foils
outliers_size_list = []
for col in foils_size.columns[:-1]:
    outliers_size_list = outliers_size_list + list(foils_size[(foils_size[col] > foils_size[col].mean()+foils_size[col].std()*3.5) |
                   (foils_size[col] < foils_size[col].mean()-foils_size[col].std()*3.5)].index)
outliers_size_list = set(outliers_size_list)

# %%
# Remove outliers based on assumptions of words
# Frequency of deathbed > car
# Removing subjects based on completetion time is not the best (they do okay)
foil_size_outliers = foils_size
foil_size_outliers = foil_size_outliers[~foil_size_outliers.index.isin(outliers_size_list)]
foil_size_outliers_melt = pd.melt(foil_size_outliers, id_vars='Random ID')
foil_size_outliers_melt.columns = ['Random ID','variable','value']

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
f, axes = plt.subplots(2, 1, figsize=(18, 7), sharex=False)
sns.despine(left=True)
sns.stripplot(x="variable", y="value", data=foils_size_melt, 
              color='.3', jitter=True, ax=axes[0])
sns.stripplot(x="variable", y="value", data=foil_size_outliers_melt, 
              color='.3', jitter=True,  ax=axes[1])
sns.boxplot(x="variable", y="value", data=foils_size_melt, whis=np.inf, ax=axes[0])
sns.boxplot(x="variable", y="value", data=foil_size_outliers_melt, whis=np.inf, ax=axes[1])
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.0)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Check foils to see if any subjs responded indiscriminately
foil_relationships = [x for x in raw.iloc[0].tolist() if x.startswith('Q37')]
foil_relationships = [x[6:] for x in foil_relationships]
foil_relationships = [x for x in raw.columns.tolist() if x.startswith('Q37.1')]
foil_relationships = raw[foil_relationships].iloc[0]
foil_relationships = [s.replace('\xe2\x80\x93', '-') for s in foil_relationships]
#foil_items = [i.split(' - ', 1)[1] for i in foil_items if ' - ' in i]
filtered_cols = [col for col in raw_reorg if col.startswith('Q37.1')]
foils = pd.DataFrame(responses[filtered_cols])
foils.columns = foil_relationships
foils['Random ID']  =raw_reorg['Random ID']
foils = foils.apply(pd.to_numeric)
foils_melt = pd.melt(foils, id_vars='Random ID')

# %%
# Check for values above means for unexpected foils
outliers_list = []
for rel in foils.columns[:-1]:
    outliers_list = outliers_list + list(foils[(foils[rel] > foils[rel].mean()+foils[rel].std()*3.5) |
                   (foils[rel] < foils[rel].mean()-foils[rel].std()*3.5)].index)
outliers_list = set(outliers_list)

# %%
# Remove outliers based on assumptions of words
foil_outliers = foils
foil_outliers = foil_outliers[~foil_outliers.index.isin(outliers_list)]
foil_outliers_melt = pd.melt(foil_outliers, id_vars='Random ID')
foil_outliers_melt.columns = ['Random ID','variable','value']

# %%
f, axes = plt.subplots(2, 1, figsize=(18, 7), sharex=False)
sns.despine(left=True)
foils_melt['variable'] = [i.split('程度 -')[1] for i in foils_melt['variable']]
foil_outliers_melt['variable'] = [i.split('程度 -')[1] for i in foil_outliers_melt['variable']]
sns.stripplot(x="variable", y="value", data=foils_melt, 
              color='.3', jitter=True, ax=axes[0])
sns.stripplot(x="variable", y="value", data=foil_outliers_melt, 
              color='.3', jitter=True,  ax=axes[1])
sns.boxplot(x="variable", y="value", data=foils_melt, whis=np.inf, ax=axes[0])
sns.boxplot(x="variable", y="value", data=foil_outliers_melt, whis=np.inf, ax=axes[1])
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.0)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Remove relationship ratings where subjects indicated that they did not 
# understand the relationships
filtered_cols = [col for col in raw_reorg if col.startswith(('Q3.1'))]
familiarity = pd.DataFrame(raw_reorg[filtered_cols])
familiarity.columns = relationships
familiarity['Random ID'] = raw_reorg['Random ID']
familiarity = familiarity.apply(pd.to_numeric)
familiarity_melt = pd.melt(familiarity, id_vars='Random ID')

# %%
# Check for values above means for unexpected foils
familiarity_list = []
for col in familiarity.columns[:-1]:
    familiarity_list = familiarity_list + list(familiarity[(familiarity[col] < 
                    familiarity[col].mean()-familiarity[col].std()*3.5)].index)
familiarity_list = set(familiarity_list)

# %%
# Remove outliers from the rest of the data
outliers_all_list = set(list(outliers_list) + list(outliers_size_list) + list(familiarity_list)+list(outliers_time_list))
dimension_frames_outliers = dimension_frames.copy()
for dim in dimension_frames_outliers:
    dimension_frames_outliers[dim] = dimension_frames[dim][~dimension_frames[dim].index.isin(outliers_all_list)]
    dimension_frames_outliers[dim] = dimension_frames_outliers[dim].apply(pd.to_numeric)

# Check total number of responses for each word with outliers excluded
num_response_outliers = pd.DataFrame(index=relationships,columns=dimensions)
for dim in dimensions:
    print(dimension_frames_outliers[dim])
    temp_df = dimension_frames_outliers[dim].count()
    temp_df.index = relationships
    num_response_outliers[dim] = temp_df

print("Total number of responses, excluding bad participants - "+str(len(dimension_frames_outliers[dim])))
print("Smallest number of ratings for a relationship - " + str(min(list(num_response_outliers.min()))))
print("Largest number of ratings for a relationship - " + str(max(list(num_response_outliers.max()))))
# Out:
#     Q4.2_373  Q4.2_375  Q4.2_376  Q4.2_377  Q4.2_378  Q4.2_379  Q4.2_380  \
# 0       59.0      69.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      56.0       NaN
# 3        NaN       NaN      58.0       NaN      94.0       NaN       NaN
# 4        NaN      72.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       89.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN      93.0      13.0      57.0       NaN       NaN
# 8        NaN       NaN      80.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN      92.0       NaN      92.0       NaN
# 10       NaN       NaN      71.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      87.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      86.0
# 13       NaN       NaN       NaN      83.0       NaN     100.0       NaN
# 14      83.0       NaN       NaN       NaN       NaN       NaN      80.0
# 16       NaN      74.0      77.0       NaN       NaN      81.0       NaN
# 17       NaN       NaN      86.0       NaN       NaN       NaN     100.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN      97.0       NaN
# 20       NaN     100.0       NaN      30.0     100.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN     100.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN      68.0       NaN       NaN
# 24       NaN      75.0       NaN       NaN       NaN       NaN      77.0
# 25       NaN       NaN       NaN      69.0       NaN      79.0       NaN
# 26      88.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      74.0       NaN      61.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN      96.0       NaN       NaN
# 29      84.0      80.0       NaN       NaN      82.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      68.0       NaN       NaN       NaN      74.0
# 32       NaN       NaN       NaN       NaN     100.0       NaN       NaN
# 33       NaN      69.0       NaN       NaN       NaN       NaN      97.0
# 34       NaN       NaN      79.0      81.0      82.0       NaN       NaN
# 35      67.0       NaN       NaN      64.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN      43.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      52.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      93.0
# 39       NaN       NaN       NaN       NaN       NaN      69.0       NaN
# 40       NaN       NaN       NaN      95.0       NaN      95.0       NaN
# 41      80.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN      83.0       NaN       NaN       NaN      88.0      70.0
# 43       NaN       NaN     100.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47      87.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      63.0       NaN
# 50       NaN       NaN       NaN      87.0      92.0       NaN       NaN
# 51       NaN      80.0      71.0       NaN       NaN       NaN       NaN
# 52       NaN      86.0       NaN       NaN       NaN       NaN      72.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN      89.0
#
#     Q4.2_381  Q4.2_382  Q4.2_383  Q4.2_384  Q4.2_385  Q4.2_386  Q4.2_387  \
# 0        NaN      56.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      50.0      64.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       99.0      17.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      59.0       NaN      82.0      94.0       NaN
# 6        NaN       NaN       NaN      93.0      91.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       90.0       NaN       NaN       NaN       NaN      70.0       NaN
# 9        NaN       NaN      85.0       NaN       NaN       NaN       NaN
# 10     100.0       NaN       NaN       NaN      97.0       NaN       NaN
# 11       NaN       NaN       NaN     100.0       NaN       NaN       NaN
# 12       NaN       NaN       NaN      90.0       NaN      80.0       NaN
# 13       NaN       NaN       NaN      94.0       NaN       NaN       NaN
# 14       NaN       NaN       NaN      84.0       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 18       NaN       NaN      81.0       NaN       NaN       NaN       0.0
# 19       NaN       NaN       NaN       NaN      96.0       NaN       9.0
# 20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21       NaN     100.0       NaN       NaN       NaN       NaN      10.0
# 22       NaN      96.0       NaN       NaN       NaN       NaN       NaN
# 23       NaN      84.0      68.0       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN      80.0       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN       NaN       4.0
# 26       NaN       NaN       NaN       NaN       NaN      90.0       NaN
# 27       NaN       NaN      67.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN      85.0       NaN      93.0       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30      83.0       NaN       NaN       NaN       NaN     100.0      50.0
# 31       NaN       NaN       NaN       NaN      73.0       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN       0.0
# 33       NaN       NaN       NaN      89.0       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 35      60.0       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN      17.0       NaN       NaN       NaN
# 37      76.0       NaN       NaN       NaN       NaN      71.0       NaN
# 38       NaN       NaN       NaN       NaN      91.0       NaN       3.0
# 39      85.0      55.0       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 41       NaN       NaN       NaN       NaN      38.0       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43       NaN     100.0       NaN       NaN       NaN       NaN       0.0
# 44     100.0      80.0       NaN       NaN     100.0       NaN       NaN
# 45       NaN       NaN       NaN      95.0      86.0       NaN      30.0
# 46       NaN       NaN       NaN       NaN       NaN      70.0      22.0
# 47      90.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN      53.0       NaN       NaN      71.0       NaN       NaN
# 50       NaN       NaN       NaN      90.0       NaN       NaN       NaN
# 51       NaN       NaN       NaN       NaN       NaN       NaN      90.0
# 52       NaN       NaN      78.0       NaN       NaN       NaN       NaN
# 53      73.0      82.0       NaN       NaN       NaN       NaN       NaN
#
#     Q4.2_388
# 0        NaN
# 2        NaN
# 3        3.0
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11      26.0
# 12       NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 17       NaN
# 18       0.0
# 19       NaN
# 20       NaN
# 21       0.0
# 22      12.0
# 23       NaN
# 24       NaN
# 25       NaN
# 26       7.0
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       4.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36       8.0
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41      29.0
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46      15.0
# 47       8.0
# 48       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
#     Q5.2_373  Q5.2_375  Q5.2_376  Q5.2_377  Q5.2_378  Q5.2_379  Q5.2_380  \
# 0       41.0      60.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      30.0       NaN
# 3        NaN       NaN      52.0       NaN       0.0       NaN       NaN
# 4        NaN     100.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       32.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN      16.0      59.0       2.0       NaN       NaN
# 8        NaN       NaN      11.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN       0.0       NaN       9.0       NaN
# 10       NaN       NaN       0.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      20.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      36.0
# 13       NaN       NaN       NaN      25.0       NaN       0.0       NaN
# 14      24.0       NaN       NaN       NaN       NaN       NaN      24.0
# 16       NaN      46.0      18.0       NaN       NaN      22.0       NaN
# 17       NaN       NaN       0.0       NaN       NaN       NaN       0.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN      31.0       NaN
# 20       NaN     100.0       NaN       0.0       0.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN      21.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 24       NaN      85.0       NaN       NaN       NaN       NaN      30.0
# 25       NaN       NaN       NaN       0.0       NaN       6.0       NaN
# 26      16.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      62.0       NaN      57.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 29       8.0      72.0       NaN       NaN       5.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      36.0       NaN       NaN       NaN      44.0
# 32       NaN       NaN       NaN       NaN       9.0       NaN       NaN
# 33       NaN     100.0       NaN       NaN       NaN       NaN       2.0
# 34       NaN       NaN      15.0      13.0      18.0       NaN       NaN
# 35      59.0       NaN       NaN      72.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN      14.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      47.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      22.0
# 39       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 40       NaN       NaN       NaN       3.0       NaN       8.0       NaN
# 41      28.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN      92.0       NaN       NaN       NaN      35.0      12.0
# 43       NaN       NaN       8.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47      18.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      32.0       NaN
# 50       NaN       NaN       NaN       7.0       8.0       NaN       NaN
# 51       NaN      87.0       7.0       NaN       NaN       NaN       NaN
# 52       NaN       7.0       NaN       NaN       NaN       NaN      44.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN      12.0
#
#     Q5.2_381  Q5.2_382  Q5.2_383  Q5.2_384  Q5.2_385  Q5.2_386  Q5.2_387  \
# 0        NaN      71.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      45.0      41.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       91.0       0.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      92.0       NaN      92.0      61.0       NaN
# 6        NaN       NaN       NaN      25.0      43.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       42.0       NaN       NaN       NaN       NaN      41.0       NaN
# 9        NaN       NaN      91.0       NaN       NaN       NaN       NaN
# 10      50.0       NaN       NaN       NaN      39.0       NaN       NaN
# 11       NaN       NaN       NaN      90.0       NaN       NaN       NaN
# 12       NaN       NaN       NaN      88.0       NaN      17.0       NaN
# 13       NaN       NaN       NaN     100.0       NaN       NaN       NaN
# 14       NaN       NaN       NaN      74.0       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 18       NaN       NaN     100.0       NaN       NaN       NaN       9.0
# 19       NaN       NaN       NaN       NaN      97.0       NaN      85.0
# 20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21       NaN     100.0       NaN       NaN       NaN       NaN       7.0
# 22       NaN      88.0       NaN       NaN       NaN       NaN       NaN
# 23       NaN      85.0      89.0       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN      87.0       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN       NaN      12.0
# 26       NaN       NaN       NaN       NaN       NaN      94.0       NaN
# 27       NaN       NaN      73.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN     100.0       NaN      64.0       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30      80.0       NaN       NaN       NaN       NaN      31.0      28.0
# 31       NaN       NaN       NaN       NaN      57.0       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN     100.0
# 33       NaN       NaN       NaN      89.0       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 35      67.0       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN      11.0       NaN       NaN       NaN
# 37      58.0       NaN       NaN       NaN       NaN      69.0       NaN
# 38       NaN       NaN       NaN       NaN      21.0       NaN      19.0
# 39     100.0      18.0       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN      13.0       NaN
# 41       NaN       NaN       NaN       NaN      38.0       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43       NaN      20.0       NaN       NaN       NaN       NaN       1.0
# 44      87.0      31.0       NaN       NaN      80.0       NaN       NaN
# 45       NaN       NaN       NaN      61.0      70.0       NaN       0.0
# 46       NaN       NaN       NaN       NaN       NaN      44.0      81.0
# 47      73.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN      26.0       NaN       NaN      73.0       NaN       NaN
# 50       NaN       NaN       NaN      91.0       NaN       NaN       NaN
# 51       NaN       NaN       NaN       NaN       NaN       NaN      82.0
# 52       NaN       NaN      11.0       NaN       NaN       NaN       NaN
# 53      83.0      87.0       NaN       NaN       NaN       NaN       NaN
#
#     Q5.2_388
# 0        NaN
# 2        NaN
# 3       54.0
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11      62.0
# 12       NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 17       NaN
# 18     100.0
# 19       NaN
# 20       NaN
# 21       1.0
# 22      11.0
# 23       NaN
# 24       NaN
# 25       NaN
# 26       5.0
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32      60.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36      81.0
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41      64.0
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46      87.0
# 47      79.0
# 48       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
#     Q6.2_373  Q6.2_375  Q6.2_376  Q6.2_377  Q6.2_378  Q6.2_379  Q6.2_380  \
# 0       37.0      31.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      35.0       NaN
# 3        NaN       NaN      67.0       NaN      77.0       NaN       NaN
# 4        NaN      97.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       71.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN      36.0      70.0      72.0       NaN       NaN
# 8        NaN       NaN      70.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN      88.0       NaN      91.0       NaN
# 10       NaN       NaN      82.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      56.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      83.0
# 13       NaN       NaN       NaN      91.0       NaN     100.0       NaN
# 14      65.0       NaN       NaN       NaN       NaN       NaN      75.0
# 16       NaN      24.0      21.0       NaN       NaN      23.0       NaN
# 17       NaN       NaN      88.0       NaN       NaN       NaN     100.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN      90.0       NaN
# 20       NaN       0.0       NaN     100.0     100.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN      89.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN      43.0       NaN       NaN
# 24       NaN      32.0       NaN       NaN       NaN       NaN      73.0
# 25       NaN       NaN       NaN      81.0       NaN      64.0       NaN
# 26       7.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      57.0       NaN      63.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN      69.0       NaN       NaN
# 29      47.0       7.0       NaN       NaN      75.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      32.0       NaN       NaN       NaN      39.0
# 32       NaN       NaN       NaN       NaN      78.0       NaN       NaN
# 33       NaN       1.0       NaN       NaN       NaN       NaN      69.0
# 34       NaN       NaN      78.0      80.0      75.0       NaN       NaN
# 35      70.0       NaN       NaN      63.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN      69.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      55.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      95.0
# 39       NaN       NaN       NaN       NaN       NaN      91.0       NaN
# 40       NaN       NaN       NaN      80.0       NaN      90.0       NaN
# 41      62.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN       7.0       NaN       NaN       NaN      74.0      69.0
# 43       NaN       NaN      98.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47      67.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      23.0       NaN
# 50       NaN       NaN       NaN       6.0       7.0       NaN       NaN
# 51       NaN      11.0       6.0       NaN       NaN       NaN       NaN
# 52       NaN       6.0       NaN       NaN       NaN       NaN      79.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN       5.0
#
#     Q6.2_381  Q6.2_382  Q6.2_383  Q6.2_384  Q6.2_385  Q6.2_386  Q6.2_387  \
# 0        NaN      25.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      43.0      30.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       75.0       0.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      58.0       NaN      79.0      72.0       NaN
# 6        NaN       NaN       NaN      60.0      68.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       60.0       NaN       NaN       NaN       NaN      65.0       NaN
# 9        NaN       NaN       4.0       NaN       NaN       NaN       NaN
# 10      72.0       NaN       NaN       NaN      81.0       NaN       NaN
# 11       NaN       NaN       NaN      21.0       NaN       NaN       NaN
# 12       NaN       NaN       NaN      65.0       NaN      74.0       NaN
# 13       NaN       NaN       NaN      25.0       NaN       NaN       NaN
# 14       NaN       NaN       NaN       8.0       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN      75.0       NaN
# 18       NaN       NaN      16.0       NaN       NaN       NaN      88.0
# 19       NaN       NaN       NaN       NaN      44.0       NaN      27.0
# 20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21       NaN       7.0       NaN       NaN       NaN       NaN      86.0
# 22       NaN      10.0       NaN       NaN       NaN       NaN       NaN
# 23       NaN       0.0      11.0       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN      30.0       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN       NaN      59.0
# 26       NaN       NaN       NaN       NaN       NaN       9.0       NaN
# 27       NaN       NaN      58.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       0.0       NaN      51.0       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30      70.0       NaN       NaN       NaN       NaN      93.0      19.0
# 31       NaN       NaN       NaN       NaN      37.0       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN      79.0
# 33       NaN       NaN       NaN      52.0       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 35      69.0       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN      45.0       NaN       NaN       NaN
# 37      72.0       NaN       NaN       NaN       NaN      72.0       NaN
# 38       NaN       NaN       NaN       NaN      91.0       NaN       1.0
# 39      91.0       4.0       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN      90.0       NaN
# 41       NaN       NaN       NaN       NaN      67.0       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43       NaN       0.0       NaN       NaN       NaN       NaN       0.0
# 44      41.0       6.0       NaN       NaN      41.0       NaN       NaN
# 45       NaN       NaN       NaN      53.0      54.0       NaN      79.0
# 46       NaN       NaN       NaN       NaN       NaN      12.0      21.0
# 47      12.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN      24.0       NaN       NaN      35.0       NaN       NaN
# 50       NaN       NaN       NaN      11.0       NaN       NaN       NaN
# 51       NaN       NaN       NaN       NaN       NaN       NaN      87.0
# 52       NaN       NaN      19.0       NaN       NaN       NaN       NaN
# 53       7.0       6.0       NaN       NaN       NaN       NaN       NaN
#
#     Q6.2_388
# 0        NaN
# 2        NaN
# 3       47.0
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11      90.0
# 12       NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 17       NaN
# 18      78.0
# 19       NaN
# 20       NaN
# 21      89.0
# 22      10.0
# 23       NaN
# 24       NaN
# 25       NaN
# 26       5.0
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32     100.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36      20.0
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41      37.0
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46      14.0
# 47      42.0
# 48       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
#     Q7.2_373  Q7.2_375  Q7.2_376  Q7.2_377  Q7.2_378  Q7.2_379  Q7.2_380  \
# 0       33.0      35.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      27.0       NaN
# 3        NaN       NaN       4.0       NaN       1.0       NaN       NaN
# 4        NaN      89.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       10.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN       7.0      11.0       1.0       NaN       NaN
# 8        NaN       NaN      30.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN      14.0       NaN       9.0       NaN
# 10       NaN       NaN       3.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      63.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      20.0
# 13       NaN       NaN       NaN      39.0       NaN      21.0       NaN
# 14      69.0       NaN       NaN       NaN       NaN       NaN      72.0
# 16       NaN      29.0      27.0       NaN       NaN      30.0       NaN
# 17       NaN       NaN       0.0       NaN       NaN       NaN       0.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN      22.0       NaN
# 20       NaN     100.0       NaN       0.0       0.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN      11.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN      49.0       NaN       NaN
# 24       NaN      27.0       NaN       NaN       NaN       NaN      24.0
# 25       NaN       NaN       NaN       4.0       NaN       3.0       NaN
# 26       9.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      79.0       NaN      65.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 29       7.0       6.0       NaN       NaN       9.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      36.0       NaN       NaN       NaN      43.0
# 32       NaN       NaN       NaN       NaN      47.0       NaN       NaN
# 33       NaN       1.0       NaN       NaN       NaN       NaN       1.0
# 34       NaN       NaN      11.0      13.0       8.0       NaN       NaN
# 35      62.0       NaN       NaN      69.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN       8.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      52.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      84.0
# 39       NaN       NaN       NaN       NaN       NaN      77.0       NaN
# 40       NaN       NaN       NaN       0.0       NaN       5.0       NaN
# 41      32.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN      35.0       NaN       NaN       NaN       6.0      11.0
# 43       NaN       NaN       2.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47       8.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      26.0       NaN
# 50       NaN       NaN       NaN       5.0       9.0       NaN       NaN
# 51       NaN      12.0      15.0       NaN       NaN       NaN       NaN
# 52       NaN      13.0       NaN       NaN       NaN       NaN      63.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN      11.0
#
#     Q7.2_381  Q7.2_382  Q7.2_383  Q7.2_384  Q7.2_385  Q7.2_386  Q7.2_387  \
# 0        NaN      24.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      13.0      17.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       80.0       0.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      17.0       NaN      14.0      16.0       NaN
# 6        NaN       NaN       NaN       4.0       4.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       65.0       NaN       NaN       NaN       NaN      60.0       NaN
# 9        NaN       NaN      29.0       NaN       NaN       NaN       NaN
# 10       5.0       NaN       NaN       NaN      12.0       NaN       NaN
# 11       NaN       NaN       NaN       8.0       NaN       NaN       NaN
# 12       NaN       NaN       NaN      10.0       NaN       5.0       NaN
# 13       NaN       NaN       NaN       0.0       NaN       NaN       NaN
# 14       NaN       NaN       NaN      21.0       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN       0.0       NaN
# 18       NaN       NaN      99.0       NaN       NaN       NaN     100.0
# 19       NaN       NaN       NaN       NaN       9.0       NaN       9.0
# 20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21       NaN       0.0       NaN       NaN       NaN       NaN      56.0
# 22       NaN      90.0       NaN       NaN       NaN       NaN       NaN
# 23       NaN       0.0      29.0       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN      30.0       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN       NaN      18.0
# 26       NaN       NaN       NaN       NaN       NaN       7.0       NaN
# 27       NaN       NaN      72.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       0.0       NaN       0.0       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30      16.0       NaN       NaN       NaN       NaN      57.0      17.0
# 31       NaN       NaN       NaN       NaN      30.0       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN      47.0
# 33       NaN       NaN       NaN       6.0       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 35      72.0       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN      31.0       NaN       NaN       NaN
# 37      71.0       NaN       NaN       NaN       NaN      71.0       NaN
# 38       NaN       NaN       NaN       NaN      89.0       NaN      88.0
# 39      58.0      57.0       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN       0.0       NaN
# 41       NaN       NaN       NaN       NaN      16.0       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43       NaN     100.0       NaN       NaN       NaN       NaN     100.0
# 44       9.0      76.0       NaN       NaN       0.0       NaN       NaN
# 45       NaN       NaN       NaN       5.0       4.0       NaN      50.0
# 46       NaN       NaN       NaN       NaN       NaN      45.0      55.0
# 47      10.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN      40.0       NaN       NaN      24.0       NaN       NaN
# 50       NaN       NaN       NaN      12.0       NaN       NaN       NaN
# 51       NaN       NaN       NaN       NaN       NaN       NaN      94.0
# 52       NaN       NaN      11.0       NaN       NaN       NaN       NaN
# 53      11.0      81.0       NaN       NaN       NaN       NaN       NaN
#
#     Q7.2_388
# 0        NaN
# 2        NaN
# 3        5.0
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11      78.0
# 12       NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 17       NaN
# 18      95.0
# 19       NaN
# 20       NaN
# 21       5.0
# 22      80.0
# 23       NaN
# 24       NaN
# 25       NaN
# 26       9.0
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32      47.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36      46.0
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41      69.0
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46      35.0
# 47      60.0
# 48       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
#     Q8.2_373  Q8.2_375  Q8.2_376  Q8.2_377  Q8.2_378  Q8.2_379  Q8.2_380  \
# 0       64.0      67.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      74.0       NaN
# 3        NaN       NaN      94.0       NaN      96.0       NaN       NaN
# 4        NaN     100.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       90.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN      87.0      94.0      91.0       NaN       NaN
# 8        NaN       NaN      80.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN      96.0       NaN      94.0       NaN
# 10       NaN       NaN      96.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      81.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      90.0
# 13       NaN       NaN       NaN      80.0       NaN     100.0       NaN
# 14     100.0       NaN       NaN       NaN       NaN       NaN     100.0
# 16       NaN      30.0      79.0       NaN       NaN      68.0       NaN
# 17       NaN       NaN     100.0       NaN       NaN       NaN     100.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN      96.0       NaN
# 20       NaN       0.0       NaN     100.0     100.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN      92.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN      83.0       NaN       NaN
# 24       NaN      19.0       NaN       NaN       NaN       NaN      79.0
# 25       NaN       NaN       NaN     100.0       NaN      91.0       NaN
# 26      91.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      64.0       NaN      76.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN     100.0       NaN       NaN
# 29      69.0      85.0       NaN       NaN      71.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      54.0       NaN       NaN       NaN      58.0
# 32       NaN       NaN       NaN       NaN     100.0       NaN       NaN
# 33       NaN      32.0       NaN       NaN       NaN       NaN      97.0
# 34       NaN       NaN      91.0      94.0      81.0       NaN       NaN
# 35      66.0       NaN       NaN      59.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN      84.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      52.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      93.0
# 39       NaN       NaN       NaN       NaN       NaN      94.0       NaN
# 40       NaN       NaN       NaN     100.0       NaN     100.0       NaN
# 41      74.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN      82.0       NaN       NaN       NaN      90.0      86.0
# 43       NaN       NaN      99.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47      21.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      88.0       NaN
# 50       NaN       NaN       NaN      95.0      90.0       NaN       NaN
# 51       NaN      82.0      91.0       NaN       NaN       NaN       NaN
# 52       NaN      92.0       NaN       NaN       NaN       NaN      68.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN      71.0
#
#     Q8.2_381  Q8.2_382  Q8.2_383  Q8.2_384  Q8.2_385  Q8.2_386  Q8.2_387  \
# 0        NaN      35.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      84.0      65.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4      100.0       0.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      52.0       NaN      75.0      70.0       NaN
# 6        NaN       NaN       NaN      92.0      91.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       40.0       NaN       NaN       NaN       NaN      60.0       NaN
# 9        NaN       NaN      67.0       NaN       NaN       NaN       NaN
# 10      99.0       NaN       NaN       NaN      95.0       NaN       NaN
# 11       NaN       NaN       NaN      79.0       NaN       NaN       NaN
# 12       NaN       NaN       NaN      97.0       NaN      93.0       NaN
# 13       NaN       NaN       NaN      91.0       NaN       NaN       NaN
# 14       NaN       NaN       NaN     100.0       NaN       NaN       NaN
# 16       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 18       NaN       NaN       0.0       NaN       NaN       NaN      17.0
# 19       NaN       NaN       NaN       NaN      96.0       NaN      77.0
# 20       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 21       NaN      94.0       NaN       NaN       NaN       NaN      32.0
# 22       NaN       6.0       NaN       NaN       NaN       NaN       NaN
# 23       NaN      41.0      42.0       NaN       NaN       NaN       NaN
# 24       NaN       NaN       NaN      77.0       NaN       NaN       NaN
# 25       NaN       NaN       NaN       NaN       NaN       NaN      14.0
# 26       NaN       NaN       NaN       NaN       NaN      96.0       NaN
# 27       NaN       NaN      62.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN     100.0       NaN     100.0       NaN       NaN
# 29       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 30     100.0       NaN       NaN       NaN       NaN      82.0      62.0
# 31       NaN       NaN       NaN       NaN      70.0       NaN       NaN
# 32       NaN       NaN       NaN       NaN       NaN       NaN       8.0
# 33       NaN       NaN       NaN      96.0       NaN       NaN       NaN
# 34       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 35      74.0       NaN       NaN       NaN       NaN       NaN       NaN
# 36       NaN       NaN       NaN      64.0       NaN       NaN       NaN
# 37      74.0       NaN       NaN       NaN       NaN      78.0       NaN
# 38       NaN       NaN       NaN       NaN      95.0       NaN      18.0
# 39      55.0       9.0       NaN       NaN       NaN       NaN       NaN
# 40       NaN       NaN       NaN       NaN       NaN     100.0       NaN
# 41       NaN       NaN       NaN       NaN      87.0       NaN       NaN
# 42       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 43       NaN       2.0       NaN       NaN       NaN       NaN       3.0
# 44     100.0      30.0       NaN       NaN     100.0       NaN       NaN
# 45       NaN       NaN       NaN      80.0      80.0       NaN      20.0
# 46       NaN       NaN       NaN       NaN       NaN      29.0      10.0
# 47      89.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       6.0       NaN       NaN      86.0       NaN       NaN
# 50       NaN       NaN       NaN      90.0       NaN       NaN       NaN
# 51       NaN       NaN       NaN       NaN       NaN       NaN       9.0
# 52       NaN       NaN      79.0       NaN       NaN       NaN       NaN
# 53      76.0       7.0       NaN       NaN       NaN       NaN       NaN
#
#     Q8.2_388
# 0        NaN
# 2        NaN
# 3       97.0
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11      67.0
# 12       NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 17       NaN
# 18     100.0
# 19       NaN
# 20       NaN
# 21      22.0
# 22      98.0
# 23       NaN
# 24       NaN
# 25       NaN
# 26      93.0
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32     100.0
# 33       NaN
# 34       NaN
# 35       NaN
# 36      78.0
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41      30.0
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46      24.0
# 47      86.0
# 48       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
#     Q9.2_373  Q9.2_375  Q9.2_376  Q9.2_377  Q9.2_378  Q9.2_379  Q9.2_380  \
# 0       43.0      33.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN      35.0       NaN
# 3        NaN       NaN      54.0       NaN      54.0       NaN       NaN
# 4        NaN       0.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6       53.0       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN      70.0      61.0      59.0       NaN       NaN
# 8        NaN       NaN      20.0       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN      63.0       NaN      80.0       NaN
# 10       NaN       NaN      50.0       NaN       NaN       NaN       NaN
# 11       NaN       NaN       NaN       NaN       NaN       NaN      79.0
# 12       NaN       NaN       NaN       NaN       NaN       NaN      90.0
# 13       NaN       NaN       NaN      47.0       NaN      37.0       NaN
# 14      67.0       NaN       NaN       NaN       NaN       NaN      76.0
# 16       NaN      19.0      39.0       NaN       NaN      37.0       NaN
# 17       NaN       NaN      20.0       NaN       NaN       NaN      30.0
# 18       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 19       NaN       NaN       NaN       NaN       NaN       5.0       NaN
# 20       NaN       0.0       NaN      60.0      60.0       NaN       NaN
# 21       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 22       NaN       NaN       NaN      13.0       NaN       NaN       NaN
# 23       NaN       NaN       NaN       NaN      35.0       NaN       NaN
# 24       NaN      25.0       NaN       NaN       NaN       NaN      29.0
# 25       NaN       NaN       NaN      61.0       NaN      79.0       NaN
# 26       9.0       NaN       NaN       NaN       NaN       NaN       NaN
# 27      69.0       NaN      67.0       NaN       NaN       NaN       NaN
# 28       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 29       2.0       1.0       NaN       NaN       1.0       NaN       NaN
# 30       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 31       NaN       NaN      54.0       NaN       NaN       NaN      67.0
# 32       NaN       NaN       NaN       NaN      63.0       NaN       NaN
# 33       NaN       5.0       NaN       NaN       NaN       NaN      86.0
# 34       NaN       NaN      69.0      67.0      70.0       NaN       NaN
# 35      65.0       NaN       NaN      73.0       NaN       NaN       NaN
# 36       NaN       NaN       NaN       NaN      26.0       NaN       NaN
# 37       NaN       NaN       NaN       NaN       NaN      52.0       NaN
# 38       NaN       NaN       NaN       NaN       NaN       NaN      59.0
# 39       NaN       NaN       NaN       NaN       NaN      51.0       NaN
# 40       NaN       NaN       NaN      55.0       NaN      70.0       NaN
# 41      90.0       NaN       NaN       NaN       NaN       NaN       NaN
# 42       NaN       7.0       NaN       NaN       NaN      33.0       4.0
# 43       NaN       NaN      10.0       NaN       NaN       NaN       NaN
# 44       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 45       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 46       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 47      53.0       NaN       NaN       NaN       NaN       NaN       NaN
# 48       NaN       NaN       NaN       NaN       NaN      23.0       NaN
# 50       NaN       NaN       NaN       8.0       6.0       NaN       NaN
# 51       NaN       8.0      10.0       NaN       NaN       NaN       NaN
# 52       NaN      21.0       NaN       NaN       NaN       NaN      61.0
# 53       NaN       NaN       NaN       NaN       NaN       NaN       5.0
#
#     Q9.2_381  Q9.2_382  Q9.2_383  Q9.2_384  Q9.2_385  Q9.2_386  Q9.2_387  \
# 0        NaN      28.0       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN      26.0      43.0       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       22.0      55.0       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN      52.0       NaN      72.0      72.0       NaN
# 6        NaN       NaN       NaN      43.0      40.0       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...
# 44        NaN        NaN        NaN        NaN        NaN        NaN
# 45        NaN        NaN        NaN        NaN        NaN        NaN
# 46        NaN        NaN        NaN        NaN        NaN        NaN
# 47       72.0        NaN        NaN        NaN        NaN        NaN
# 48        NaN        NaN        NaN        NaN        NaN       68.0
# 50        NaN        NaN        NaN       80.0       73.0        NaN
# 51        NaN       63.0       68.0        NaN        NaN        NaN
# 52        NaN       70.0        NaN        NaN        NaN        NaN
# 53        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Q35.2_380  Q35.2_381  Q35.2_382  Q35.2_383  Q35.2_384  Q35.2_385  \
# 0         NaN        NaN       35.0        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN       60.0
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN      100.0        0.0        NaN        NaN        NaN
# 5         NaN        NaN        NaN       28.0        NaN       73.0
# 6         NaN        NaN        NaN        NaN       91.0       94.0
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN       80.0        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN       54.0        NaN        NaN
# 10        NaN       95.0        NaN        NaN        NaN       92.0
# 11       91.0        NaN        NaN        NaN       51.0        NaN
# 12       84.0        NaN        NaN        NaN       70.0        NaN
# 13        NaN        NaN        NaN        NaN       90.0        NaN
# 14       78.0        NaN        NaN        NaN       74.0        NaN
# 16        NaN        NaN        NaN        NaN        NaN        NaN
# 17       91.0        NaN        NaN        NaN        NaN        NaN
# 18        NaN        NaN        NaN       50.0        NaN        NaN
# 19        NaN        NaN        NaN        NaN        NaN       88.0
# 20        NaN        NaN        NaN        NaN        NaN        NaN
# 21        NaN        NaN       95.0        NaN        NaN        NaN
# 22        NaN        NaN       64.0        NaN        NaN        NaN
# 23        NaN        NaN        1.0       43.0        NaN        NaN
# 24       76.0        NaN        NaN        NaN       69.0        NaN
# 25        NaN        NaN        NaN        NaN        NaN        NaN
# 26        NaN        NaN        NaN        NaN        NaN        NaN
# 27        NaN        NaN        NaN       69.0        NaN        NaN
# 28        NaN        NaN        NaN       13.0        NaN       83.0
# 29        NaN        NaN        NaN        NaN        NaN        NaN
# 30        NaN       83.0        NaN        NaN        NaN        NaN
# 31       73.0        NaN        NaN        NaN        NaN       67.0
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33       68.0        NaN        NaN        NaN       71.0        NaN
# 34        NaN        NaN        NaN        NaN        NaN        NaN
# 35        NaN       74.0        NaN        NaN        NaN        NaN
# 36        NaN        NaN        NaN        NaN       56.0        NaN
# 37        NaN       77.0        NaN        NaN        NaN        NaN
# 38       91.0        NaN        NaN        NaN        NaN       90.0
# 39        NaN       74.0        6.0        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN
# 41        NaN        NaN        NaN        NaN        NaN       37.0
# 42       87.0        NaN        NaN        NaN        NaN        NaN
# 43        NaN        NaN        0.0        NaN        NaN        NaN
# 44        NaN      100.0        9.0        NaN        NaN       86.0
# 45        NaN        NaN        NaN        NaN       96.0       94.0
# 46        NaN        NaN        NaN        NaN        NaN        NaN
# 47        NaN       72.0        NaN        NaN        NaN        NaN
# 48        NaN        NaN       27.0        NaN        NaN       83.0
# 50        NaN        NaN        NaN        NaN       87.0        NaN
# 51        NaN        NaN        NaN        NaN        NaN        NaN
# 52       85.0        NaN        NaN       77.0        NaN        NaN
# 53       59.0       83.0       54.0        NaN        NaN        NaN
#
#     Q35.2_386  Q35.2_387  Q35.2_388
# 0         NaN        NaN        NaN
# 2        76.0        NaN        NaN
# 3         NaN        NaN       45.0
# 4         NaN        NaN        NaN
# 5        83.0        NaN        NaN
# 6         NaN        NaN        NaN
# 7         NaN        NaN        NaN
# 8        75.0        NaN        NaN
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN        NaN       11.0
# 12       75.0        NaN        NaN
# 13        NaN        NaN        NaN
# 14        NaN        NaN        NaN
# 16        NaN        NaN        NaN
# 17       70.0        NaN        NaN
# 18        NaN        0.0       12.0
# 19        NaN        5.0        NaN
# 20        NaN        NaN        NaN
# 21        NaN       10.0        4.0
# 22        NaN        NaN       12.0
# 23        NaN        NaN        NaN
# 24        NaN        NaN        NaN
# 25        NaN       16.0        NaN
# 26       84.0        NaN       16.0
# 27        NaN        NaN        NaN
# 28        NaN        NaN        NaN
# 29        NaN        NaN        NaN
# 30       89.0       19.0        NaN
# 31        NaN        NaN        NaN
# 32        NaN       87.0       83.0
# 33        NaN        NaN        NaN
# 34        NaN        NaN        NaN
# 35        NaN        NaN        NaN
# 36        NaN        NaN       19.0
# 37       76.0        NaN        NaN
# 38        NaN       10.0        NaN
# 39        NaN        NaN        NaN
# 40       81.0        NaN        NaN
# 41        NaN        NaN       70.0
# 42        NaN        NaN        NaN
# 43        NaN        0.0        NaN
# 44        NaN        NaN        NaN
# 45        NaN        8.0        NaN
# 46       44.0       11.0       31.0
# 47        NaN        NaN        1.0
# 48        NaN        NaN        NaN
# 50        NaN        NaN        NaN
# 51        NaN       89.0        NaN
# 52        NaN        NaN        NaN
# 53        NaN        NaN        NaN
#     Q36.2_373  Q36.2_375  Q36.2_376  Q36.2_377  Q36.2_378  Q36.2_379  \
# 0        55.0       43.0        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN       55.0
# 3         NaN        NaN        5.0        NaN       54.0        NaN
# 4         NaN        0.0        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         3.0        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN       24.0        6.0       31.0        NaN
# 8         NaN        NaN       90.0        NaN        NaN        NaN
# 9         NaN        NaN        NaN       87.0        NaN       79.0
# 10        NaN        NaN        0.0        NaN        NaN        NaN
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 12        NaN        NaN        NaN        NaN        NaN        NaN
# 13        NaN        NaN        NaN        0.0        NaN       13.0
# 14       21.0        NaN        NaN        NaN        NaN        NaN
# 16        NaN       30.0       44.0        NaN        NaN       35.0
# 17        NaN        NaN       51.0        NaN        NaN        NaN
# 18        NaN        NaN        NaN        NaN        NaN        NaN
# 19        NaN        NaN        NaN        NaN        NaN        0.0
# 20        NaN        0.0        NaN        0.0       71.0        NaN
# 21        NaN        NaN        NaN        NaN        NaN        NaN
# 22        NaN        NaN        NaN       26.0        NaN        NaN
# 23        NaN        NaN        NaN        NaN       64.0        NaN
# 24        NaN       18.0        NaN        NaN        NaN        NaN
# 25        NaN        NaN        NaN       92.0        NaN       74.0
# 26       61.0        NaN        NaN        NaN        NaN        NaN
# 27       61.0        NaN       79.0        NaN        NaN        NaN
# 28        NaN        NaN        NaN        NaN       66.0        NaN
# 29        2.0        3.0        NaN        NaN        7.0        NaN
# 30        NaN        NaN        NaN        NaN        NaN        NaN
# 31        NaN        NaN       35.0        NaN        NaN        NaN
# 32        NaN        NaN        NaN        NaN       67.0        NaN
# 33        NaN        0.0        NaN        NaN        NaN        NaN
# 34        NaN        NaN       53.0       50.0       60.0        NaN
# 35       69.0        NaN        NaN       76.0        NaN        NaN
# 36        NaN        NaN        NaN        NaN       48.0        NaN
# 37        NaN        NaN        NaN        NaN        NaN       52.0
# 38        NaN        NaN        NaN        NaN        NaN        NaN
# 39        NaN        NaN        NaN        NaN        NaN        0.0
# 40        NaN        NaN        NaN        4.0        NaN       20.0
# 41       63.0        NaN        NaN        NaN        NaN        NaN
# 42        NaN       44.0        NaN        NaN        NaN       76.0
# 43        NaN        NaN       53.0        NaN        NaN        NaN
# 44        NaN        NaN        NaN        NaN        NaN        NaN
# 45        NaN        NaN        NaN        NaN        NaN        NaN
# 46        NaN        NaN        NaN        NaN        NaN        NaN
# 47        2.0        NaN        NaN        NaN        NaN        NaN
# 48        NaN        NaN        NaN        NaN        NaN       62.0
# 50        NaN        NaN        NaN       61.0       71.0        NaN
# 51        NaN       63.0       77.0        NaN        NaN        NaN
# 52        NaN        8.0        NaN        NaN        NaN        NaN
# 53        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Q36.2_380  Q36.2_381  Q36.2_382  Q36.2_383  Q36.2_384  Q36.2_385  \
# 0         NaN        NaN       38.0        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN       52.0
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        0.0        0.0        NaN        NaN        NaN
# 5         NaN        NaN        NaN        0.0        NaN       60.0
# 6         NaN        NaN        NaN        NaN        5.0        6.0
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN       20.0        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        0.0        NaN        NaN
# 10        NaN        0.0        NaN        NaN        NaN        0.0
# 11       72.0        NaN        NaN        NaN        0.0        NaN
# 12        9.0        NaN        NaN        NaN        5.0        NaN
# 13        NaN        NaN        NaN        NaN        0.0        NaN
# 14       22.0        NaN        NaN        NaN       20.0        NaN
# 16        NaN        NaN        NaN        NaN        NaN        NaN
# 17       51.0        NaN        NaN        NaN        NaN        NaN
# 18        NaN        NaN        NaN        0.0        NaN        NaN
# 19        NaN        NaN        NaN        NaN        NaN        0.0
# 20        NaN        NaN        NaN        NaN        NaN        NaN
# 21        NaN        NaN        0.0        NaN        NaN        NaN
# 22        NaN        NaN       18.0        NaN        NaN        NaN
# 23        NaN        NaN       12.0        6.0        NaN        NaN
# 24       17.0        NaN        NaN        NaN       19.0        NaN
# 25        NaN        NaN        NaN        NaN        NaN        NaN
# 26        NaN        NaN        NaN        NaN        NaN        NaN
# 27        NaN        NaN        NaN       68.0        NaN        NaN
# 28        NaN        NaN        NaN        0.0        NaN       18.0
# 29        NaN        NaN        NaN        NaN        NaN        NaN
# 30        NaN        0.0        NaN        NaN        NaN        NaN
# 31       39.0        NaN        NaN        NaN        NaN       29.0
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33       66.0        NaN        NaN        NaN       52.0        NaN
# 34        NaN        NaN        NaN        NaN        NaN        NaN
# 35        NaN       84.0        NaN        NaN        NaN        NaN
# 36        NaN        NaN        NaN        NaN       29.0        NaN
# 37        NaN       74.0        NaN        NaN        NaN        NaN
# 38       92.0        NaN        NaN        NaN        NaN        5.0
# 39        NaN        0.0        0.0        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN
# 41        NaN        NaN        NaN        NaN        NaN       39.0
# 42       62.0        NaN        NaN        NaN        NaN        NaN
# 43        NaN        NaN       53.0        NaN        NaN        NaN
# 44        NaN       39.0        0.0        NaN        NaN       20.0
# 45        NaN        NaN        NaN        NaN       50.0       51.0
# 46        NaN        NaN        NaN        NaN        NaN        NaN
# 47        NaN        3.0        NaN        NaN        NaN        NaN
# 48        NaN        NaN       23.0        NaN        NaN       76.0
# 50        NaN        NaN        NaN        NaN       19.0        NaN
# 51        NaN        NaN        NaN        NaN        NaN        NaN
# 52       20.0        NaN        NaN        6.0        NaN        NaN
# 53       69.0       37.0        8.0        NaN        NaN        NaN
#
#     Q36.2_386  Q36.2_387  Q36.2_388
# 0         NaN        NaN        NaN
# 2        61.0        NaN        NaN
# 3         NaN        NaN       17.0
# 4         NaN        NaN        NaN
# 5        63.0        NaN        NaN
# 6         NaN        NaN        NaN
# 7         NaN        NaN        NaN
# 8        60.0        NaN        NaN
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN        NaN       61.0
# 12        3.0        NaN        NaN
# 13        NaN        NaN        NaN
# 14        NaN        NaN        NaN
# 16        NaN        NaN        NaN
# 17       50.0        NaN        NaN
# 18        NaN       11.0        7.0
# 19        NaN        0.0        NaN
# 20        NaN        NaN        NaN
# 21        NaN        0.0        0.0
# 22        NaN        NaN       19.0
# 23        NaN        NaN        NaN
# 24        NaN        NaN        NaN
# 25        NaN       59.0        NaN
# 26        8.0        NaN       71.0
# 27        NaN        NaN        NaN
# 28        NaN        NaN        NaN
# 29        NaN        NaN        NaN
# 30        0.0        0.0        NaN
# 31        NaN        NaN        NaN
# 32        NaN       67.0       76.0
# 33        NaN        NaN        NaN
# 34        NaN        NaN        NaN
# 35        NaN        NaN        NaN
# 36        NaN        NaN       41.0
# 37       71.0        NaN        NaN
# 38        NaN        5.0        NaN
# 39        NaN        NaN        NaN
# 40       13.0        NaN        NaN
# 41        NaN        NaN       41.0
# 42        NaN        NaN        NaN
# 43        NaN       79.0        NaN
# 44        NaN        NaN        NaN
# 45        NaN       79.0        NaN
# 46       46.0       20.0       10.0
# 47        NaN        NaN        2.0
# 48        NaN        NaN        NaN
# 50        NaN        NaN        NaN
# 51        NaN       17.0        NaN
# 52        NaN        NaN        NaN
# 53        NaN        NaN        NaN
# Total number of responses, excluding bad participants - 51
# Smallest number of ratings for a relationship - 7
# Largest number of ratings for a relationship - 12

# %%
result_dict = dimension_frames_outliers
with pd.ExcelWriter('output_data/dict_results/group_sup.xlsx')as writer:
    for dim in result_dict.keys():
        temp_df = result_dict[dim]
        temp_df.columns = relationships
        temp_df.to_excel(writer, sheet_name = dim)

# %% [markdown]
# ## Demographics

# %%
filtered_demo = [col for col in raw_reorg if col.startswith('Q39')]
response_demographic = raw_reorg.loc[:,filtered_demo]
response_demographic = response_demographic[~response_demographic.index.isin(outliers_all_list)]
response_demographic.columns = ['Age','Gender','Race','Ethnicity',
                                'Highest education','First language','First language alternative']
response_demographic.head()
# Out:
#        Age Gender Race Ethnicity Highest education First language  \
# 0  55 - 64      女   汉族       NaN              高中以下              是
# 2  18 - 24      女   汉族       NaN              大学本科              是
# 3  18 - 24      女   汉族       NaN              大学本科              是
# 4  35 - 44      男   汉族       NaN              大学本科              是
# 5  18 - 24      女   汉族       NaN              大学本科              是
#
#   First language alternative
# 0                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN

# %% [markdown]
# ### Gender

# %%
response_demographic['Gender'][response_demographic['Gender'].isna()] = 'No response'
response_demographic['Gender'].value_counts()
# Out:
# 男    30
# 女    21
# Name: Gender, dtype: int64

# %% [markdown]
# ### Age

# %%
response_demographic['Age'][response_demographic['Age'].isna()] = 'No response'
response_demographic['Age'].value_counts()
# Out:
# 18 - 24        33
# 25 - 34        12
# 35 - 44         4
# 55 - 64         1
# No response     1
# Name: Age, dtype: int64

# %% [markdown]
# ### Race

# %%
response_demographic['Race'][response_demographic['Race'].isna()] = 'No response'
response_demographic['Race'][response_demographic['Race'].isna()] = 'No response'
response_demographic['Race'].value_counts()
# Out:
# 汉族    51
# Name: Race, dtype: int64

# %% [markdown]
# ### Highest education

# %%
response_demographic['Highest education'][response_demographic['Highest education'].isna()] = 'No response'
response_demographic['Highest education'][response_demographic['Highest education'].isna()] = 'No response'
response_demographic['Highest education'].value_counts()
# Out:
# 大学本科      41
# 硕士         5
# 大专         3
# 高中以下       1
# 博士及博士后     1
# Name: Highest education, dtype: int64

# %% [markdown]
# ### First language

# %%
response_demographic['First language'][response_demographic['First language'].isna()] = 'No response'
response_demographic['First language'][response_demographic['First language'].isna()] = 'No response'
response_demographic['First language'].value_counts()
# Out:
# 是    51
# Name: First language, dtype: int64

# %% [markdown]
# ## Heatmap

# %%
dim_rel = pd.DataFrame(columns = relationships)
count=0
for dim in dimensions:
    dim_rel.loc[count] = dimension_frames_outliers[dim].mean().tolist()
    count = count + 1
dim_rel.index = dimensions
dim_rel.to_csv('output_data/cleaning_results/group_dim_rel_33d_sup.csv')

plt.figure(figsize=(30,15))
sns.heatmap(dim_rel, center=50,cmap="RdBu_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## merge or drop

# %%
# Reload the CHN_dim_rel_scaled.csv file
sup_data = pd.read_csv("output_data/cleaning_results/group_dim_rel_33d_sup.csv", index_col=0)
# Load the group_dim_rel_scaled_33d.csv file
group_data = pd.read_csv("output_data/cleaning_results/group_dim_rel_33d.csv", index_col=0)

# Concatenate the two dataframes
merged_data = pd.concat([group_data, sup_data], axis = 1)
# Save the merged dataframe to a new csv file
merged_data.to_csv("output_data/cleaning_results/group_dim_rel_33d_all.csv", index=True)

merged_data.shape
# Out:
# (33, 40)

# %%
dim_rel_scaled = preprocessing.scale(merged_data.transpose())
dim_rel_scaled = pd.DataFrame(dim_rel_scaled,index=merged_data.columns,columns=merged_data.index)
dim_rel_scaled.to_csv('output_data/cleaning_results/group_dim_rel_scaled_33d_all.csv')

# %%
# 读取原始CSV文件
df = pd.read_csv('output_data/cleaning_results/group_dim_rel_scaled_33d_all.csv')

# 删除特定行
df = df[df.iloc[:, 0].isin(['Gang Member-Rival Gang Member','Managers - Investors','Investor-Entrepreneur','Party A-Party B (in Contract)','Republic, democratic']) == False]

# 保存到一个新的CSV文件
df.to_csv('output_data/cleaning_results/group_dim_rel_scaled_33d_all_copy.csv', index=False)

# %% [markdown]
# # PCA

# %%
library(FactoMineR)
library(factoextra)#fviz_eig
library(psych)

library(ggplot2)
library(corrplot)
library(RColorBrewer)

library(tidyverse)
library(reshape)#melt
library(nFactors)#optimal number of components

# %% [markdown]
# ## optimal dimensions
# plotnScree:https://rdrr.io/cran/nFactors/src/R/plotnScree.R

# %%
plotnScree <-
function (nScree,
          elbow = 3,
          legend = TRUE,
          ylab   = "Eigenvalues",
          xlab   = "Components",
          main   = "Non Graphical Solutions to Scree Test")
          {
   if (!inherits(nScree, "nScree"))  stop("Method is only for nScree objects")
   #if (!exists("legend", mode="logical") ) legend <- TRUE                                   # To develop
   #if (!exists("ylab"))                    ylab <- "Eigenvalues"                            # To develop
   #if (!exists("xlab"))                    xlab <- "Components"                             # To develop
   #if (!exists("main"))                    main <- "Non Graphical Solutions to Scree Test"  # To develop
   if (nScree$Model == "components") nkaiser = "Eigenvalues (>mean  = " else nkaiser = "Eigenvalues (>0 = "
   if (nScree$Model == "factors")  xlab   = "Factors"
   par(col   = 1, pch = 1)     # Color and symbol for usual scree
   par(mfrow = c(1,1),lwd=2)
   eig        <- nScree$Analysis$Eigenvalues
   k          <- 1:length(eig)
   #plotuScree(x=eig, ...)                                                                   # To develop
   plotuScree(x=eig, main=main, xlab=xlab, ylab=ylab)
   nk         <- length(eig)
   noc        <- nScree$Components$noc
   vp.p       <- lm(eig[c(noc+1,nk)] ~ k[c(noc+1,nk)])
   x          <- sum(c(1,1) * coef(vp.p))
   y          <- sum(c(1,nk)* coef(vp.p))
   par(col = 10)            # Color for optimal coordinates
   lines(k[c(1,nk)],c(x,y),lwd=1.8)
   par(col = 11,pch=2)            # Color and symbol for parallel analysis
   lines(1:nk, nScree$Analysis$Par.Analysis, type = "b",lwd=1.8)
   if (legend == TRUE) {
     leg.txt  <- c(paste("Parallel Analysis (n = ",nScree$Components$nparallel,")"),
                 c(paste("Kaiser-Guttman rule (n = ",nScree$Components$nkaiser,")")),
                 c(paste("Cattell’s scree test (n = ",elbow,")")),
                 c(paste("Optimal Coordinates (n = ",nScree$Components$noc,")")) )
     legend("topright",
            legend   = leg.txt,
            pch      = c('△','_','○','_'),
            text.col = c(3,4,1,2), 
            col = c(3,4,1,2),
            cex = 1.3)
     }
   naf        <-   nScree$Components$naf
   text(x = noc ,    y = eig[noc],     label = " (OC)", cex = 1, adj = c(0,0), col = 2)
#    text(x = naf + 1, y = eig[naf + 1], label = " (AF)", cex = .70, adj = c(0,0), col = 4)
   }

# %%
# import relationship dimension ratings scaled from the Data cleaning's output
dim_rel_scaled = read.csv('output/group_dim_rel_scaled_33d_all.csv', row.names=1,encoding='UTF-8')

# Parallel analysis, Optimal Coordinates, and  Cattell's Scree Test
ev <- eigen(cor(dim_rel_scaled)) # get eigenvalues
ap <- parallel(subject=nrow(dim_rel_scaled),var=ncol(dim_rel_scaled),model="components",rep=5000,cent=.05) 
nS <- nScree(x=ev$values, model = "components",aparallel=ap$eigen$qevpea) # "qevpea" indicate 95 centile given cent=.05

# %%
nS$Analysis$Cumu[1:5]
# Out:
# [1] 0.4246053 0.6401826 0.7248880 0.8068935 0.8523288

# %%
options(repr.plot.width=8,repr.plot.height=8)
plotnScree(nS, elbow = 3,legend=TRUE, main = NULL)
abline(h = 1, col=4, lty=1,lwd =1.8) # Kaiser-Guttman Rule
# Out:
# plot without title

# %%
png("output_graph/optimal_components_all.png",
    family = 'sans',units='in',width=8,height=8,res=300)
plotnScree(nS,elbow = 3, legend=TRUE, main = NULL)
abline(h = 1, col=4, lty=1,lwd =1.8) # Kaiser-Guttman Rule
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## loading score

# %%
dim_rel.pca = prcomp(dim_rel_scaled)
ncomp = 5

loadings_none = dim_rel.pca$rotation[,1:ncomp]%*% diag(dim_rel.pca$sdev,ncomp,ncomp)
scores_none = dim_rel.pca$x[,1:ncomp] 

loadings_var = varimax(loadings_none)$loadings
scores_var = scale(scores_none) %*% varimax(loadings_none)$rotmat
loadings_var

write.csv(loadings_var,'output_data/pca_results/group_loadings_var_all.csv')
write.csv(scores_var,'output_data/pca_results/group_scores_var_all.csv')
# Out:
# Loadings:
#                            [,1]   [,2]   [,3]   [,4]   [,5]
# Valence.Evaluation          0.135               -0.452 -0.844
# Equality                   -0.165 -0.159 -0.874  0.246
# Activity.Intensity          0.526         0.181 -0.780
# Socioemotional              0.705 -0.618               -0.121
# Formality.and.Regulation   -0.401  0.843        -0.224
# Intimacy                    0.612 -0.269        -0.556 -0.421
# Visibility                 -0.153  0.863         0.405
# Communal.Sharing            0.869 -0.106        -0.273 -0.235
# Expected.Reciprocity       -0.787  0.216 -0.237
# Strategic                  -0.664  0.572                0.410
# Concreteness               -0.814        -0.232
# Uniqueness                  0.364 -0.589        -0.549  0.225
# Love.Expression             0.764 -0.314 -0.118 -0.214 -0.336
# Information.Exchange        0.104  0.452        -0.828 -0.177
# Money.Exchange             -0.888        -0.198         0.202
# Goods.Exchange             -0.752  0.129 -0.346  0.343
# Service.Exchange           -0.700  0.419               -0.362
# Attachment                  0.701 -0.294        -0.403 -0.369
# Mating                      0.378 -0.749 -0.135 -0.136
# Conflict                   -0.131        -0.109  0.321  0.901
# Negotiation                -0.502  0.319 -0.715        -0.115
# Coercion                   -0.163         0.135  0.283  0.902
# Importance.for.society             0.857 -0.266 -0.202
# Importance.for.individuals  0.363        -0.176 -0.735 -0.415
# Affiliation.Coalition       0.136  0.187  0.120 -0.840 -0.308
# Occupational               -0.592  0.630  0.232 -0.395
# Activeness                  0.120 -0.261        -0.851 -0.310
# Endurance                   0.702               -0.529
# Synchronicity              -0.164         0.123 -0.846 -0.261
# Spatial.Distance                          0.322 -0.797 -0.282
# Morality                    0.558  0.448 -0.175 -0.350 -0.522
# Trust                       0.348  0.176        -0.645 -0.632
# Generation.Gap              0.599         0.542 -0.272 -0.166
#
#                 [,1]  [,2]  [,3]  [,4]  [,5]
# SS loadings    9.192 5.409 2.298 7.414 4.535
# Proportion Var 0.279 0.164 0.070 0.225 0.137
# Cumulative Var 0.279 0.442 0.512 0.737 0.874

# %%
loadings_var = read.csv('output_data/pca_results/group_loadings_var_all.csv',row.names=1)

# %%
loadings_var_reorder = as.data.frame(loadings_var[,1:ncomp])
colnames(loadings_var_reorder) = c('Exchange','Formality','Equality','Activeness','Valence')

#filter each row's max loading, and attribute it to correspnding column.
order_list = c()
for (row in c(1:33)){
    temp_max = abs(loadings_var_reorder[row,1])
    n = 1
    for (col in c(2:5)){
        temp = abs(loadings_var_reorder[row,col])
        if (temp > temp_max){
            temp_max = temp
            n = col
        }
        
    }
    order_list[row] = n
}
loadings_var_reorder = loadings_var_reorder %>% mutate(order = order_list)
RC1 = loadings_var_reorder %>% filter(order==1) %>% arrange(desc(Exchange))
RC2 = loadings_var_reorder %>% filter(order==2) %>% arrange(desc(Formality))
RC3 = loadings_var_reorder %>% filter(order==3) %>% arrange(desc(Equality))
RC4 = loadings_var_reorder %>% filter(order==4) %>% arrange(desc(Activeness))
RC5 = loadings_var_reorder %>% filter(order==5) %>% arrange(desc(Valence))

loadings_var_reorder = rbind(RC1,RC2,RC3,RC4,RC5)
loadings_var_reorder = loadings_var_reorder[1:5]

options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1.0,1.0,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1.0,1.0),cl.ratio = 0.4,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %%
png("output_graph/group_loading_bipolar_all.png", bg="transparent",
    family = 'sans',units='in',width=6,height=10,res=300)
colnames(loadings_var_reorder) = rep('',5)
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1.0,1.0),cl.ratio = 0.4,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(100))
dev.off()
# Out:
# png
#   2

# %% [markdown]
# ## relationship score

# %%
library(ggrepel)
scores_var = read.csv('output_data/pca_results/group_scores_var_all.csv',row.names=1)
scores_var_plot = data.frame(scores_var)
colnames(scores_var_plot) = c('Exchange','Formality','Equality','Activeness','Valence')
scores_var_plot['Equality'] = -scores_var_plot['Equality']
scores_var_plot['Activeness'] = -scores_var_plot['Activeness']
scores_var_plot['Exchange'] = -scores_var_plot['Exchange']
scores_var_plot['Valence'] = -scores_var_plot['Valence']

scores_var_plot['rel'] = rownames(scores_var_plot)

# %%
Plot_scatter = 
theme_bw()+
theme(panel.border=element_blank(),panel.grid=element_blank(),
      panel.background = element_rect(fill = 'black'), 
      axis.title=element_text(size=28,face='bold'),
      axis.text=element_text(size=28,face='bold'))

# %%
randomseed = 2022
options(repr.plot.height=10.82,repr.plot.width=13.3)
ggplot(scores_var_plot, aes(x=Formality,y=Activeness))+
geom_point(color='#DAFD59',alpha=0.8,size=4.5)+
geom_text_repel(aes(label=rel),size=6.5,
                seed = randomseed,,color='white',
                min.segment.length = Inf)+
geom_hline(yintercept = 0,linetype='dashed',size = 2,color='white')+
geom_vline(xintercept = 0,linetype='dashed',size = 2,color='white')+
Plot_scatter


ggplot(scores_var_plot, aes(x=Valence,y=Exchange))+
geom_point(color='#DAFD59',alpha=0.8,size=4.5)+
geom_text_repel(aes(label=rel),size=6.5,
                seed = randomseed,,color='white',
                min.segment.length = Inf)+
geom_hline(yintercept = 0,linetype='dashed',size = 2,color='white')+
geom_vline(xintercept = 0,linetype='dashed',size = 2,color='white')+
Plot_scatter


ggplot(scores_var_plot, aes(x=Valence,y=Equality))+
geom_point(color='#DAFD59',alpha=0.8,size=4.5)+
geom_text_repel(aes(label=rel),size=6.5,
                seed = randomseed,,color='white',
                min.segment.length = Inf)+
geom_hline(yintercept = 0,linetype='dashed',size = 2,color='white')+
geom_vline(xintercept = 0,linetype='dashed',size = 2,color='white')+
Plot_scatter
# Out:
# Warning message:
# "ggrepel: 1 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# Warning message:
# "ggrepel: 14 unlabeled data points (too many overlaps). Consider increasing max.overlaps"
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## other models

# %% [markdown]
# ## 2 dimensions

# %%
dim_rel.pca = prcomp(dim_rel_scaled)
ncomp = 2

loadings_none = dim_rel.pca$rotation[,1:ncomp]%*% diag(dim_rel.pca$sdev,ncomp,ncomp)
scores_none = dim_rel.pca$x[,1:ncomp] 

loadings_var = varimax(loadings_none)$loadings
scores_var = scale(scores_none) %*% varimax(loadings_none)$rotmat

write.csv(loadings_var,'output_data/pca_results/triadic_loadings_var_all_2c.csv')
write.csv(scores_var,'output_data/pca_results/triadic_scores_var_all_2c.csv')

# %%
loadings_var_reorder = as.data.frame(loadings_var[,1:ncomp])

#filter each row's max loading, and attribute it to correspnding column.
order_list = c()
for (row in c(1:33)){
    temp_max = abs(loadings_var_reorder[row,1])
    n = 1
    for (col in c(2)){
        temp = abs(loadings_var_reorder[row,col])
        if (temp > temp_max){
            temp_max = temp
            n = col
        }
        
    }
    order_list[row] = n
}
loadings_var_reorder = loadings_var_reorder %>% mutate(order = order_list)
RC1 = loadings_var_reorder %>% filter(order==1) %>% arrange(desc(V1))
RC2 = loadings_var_reorder %>% filter(order==2) %>% arrange(desc(V2))

loadings_var_reorder = rbind(RC1,RC2)
loadings_var_reorder = loadings_var_reorder[1:2]
colnames(loadings_var_reorder) = c('Valence','Formality')

options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 1.2,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %% [markdown]
# ## 3 dimensions

# %%
dim_rel.pca = prcomp(dim_rel_scaled)
ncomp = 3

loadings_none = dim_rel.pca$rotation[,1:ncomp]%*% diag(dim_rel.pca$sdev,ncomp,ncomp)
scores_none = dim_rel.pca$x[,1:ncomp] 

loadings_var = varimax(loadings_none)$loadings
scores_var = scale(scores_none) %*% varimax(loadings_none)$rotmat

write.csv(loadings_var,'output_data/pca_results/triadic_loadings_var_all_3c.csv')
write.csv(scores_var,'output_data/pca_results/triadic_scores_var_all_3c.csv')

# %%
loadings_var_reorder = as.data.frame(loadings_var[,1:ncomp])

#filter each row's max loading, and attribute it to correspnding column.
order_list = c()
for (row in c(1:33)){
    temp_max = abs(loadings_var_reorder[row,1])
    n = 1
    for (col in c(2:3)){
        temp = abs(loadings_var_reorder[row,col])
        if (temp > temp_max){
            temp_max = temp
            n = col
        }
        
    }
    order_list[row] = n
}
loadings_var_reorder = loadings_var_reorder %>% mutate(order = order_list)
RC1 = loadings_var_reorder %>% filter(order==1) %>% arrange(desc(V1))
RC2 = loadings_var_reorder %>% filter(order==2) %>% arrange(desc(V2))
RC3 = loadings_var_reorder %>% filter(order==3) %>% arrange(desc(V3))

loadings_var_reorder = rbind(RC1,RC2,RC3)
loadings_var_reorder = loadings_var_reorder[1:3]
colnames(loadings_var_reorder) = c('Valence','Formality','Exchange')

options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 0.8,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %% [markdown]
# ## 4 dimensions

# %%
dim_rel.pca = prcomp(dim_rel_scaled)
ncomp = 4

loadings_none = dim_rel.pca$rotation[,1:ncomp]%*% diag(dim_rel.pca$sdev,ncomp,ncomp)
scores_none = dim_rel.pca$x[,1:ncomp] 

loadings_var = varimax(loadings_none)$loadings
scores_var = scale(scores_none) %*% varimax(loadings_none)$rotmat

write.csv(loadings_var,'output_data/pca_results/triadic_loadings_var_all_4c.csv')
write.csv(scores_var,'output_data/pca_results/triadic_scores_var_all_4c.csv')

# %%
loadings_var_reorder = as.data.frame(loadings_var[,1:ncomp])

#filter each row's max loading, and attribute it to correspnding column.
order_list = c()
for (row in c(1:33)){
    temp_max = abs(loadings_var_reorder[row,1])
    n = 1
    for (col in c(2:4)){
        temp = abs(loadings_var_reorder[row,col])
        if (temp > temp_max){
            temp_max = temp
            n = col
        }
        
    }
    order_list[row] = n
}
loadings_var_reorder = loadings_var_reorder %>% mutate(order = order_list)
RC1 = loadings_var_reorder %>% filter(order==1) %>% arrange(desc(V1))
RC2 = loadings_var_reorder %>% filter(order==2) %>% arrange(desc(V2))
RC3 = loadings_var_reorder %>% filter(order==3) %>% arrange(desc(V3))
RC4 = loadings_var_reorder %>% filter(order==4) %>% arrange(desc(V4))

loadings_var_reorder = rbind(RC1,RC2,RC3,RC4)
loadings_var_reorder = loadings_var_reorder[1:4]
colnames(loadings_var_reorder) = c('Exchange','Formality','Valence','Activeness')

options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 0.6,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %% [markdown]
# ## 6 dimensions

# %%
dim_rel.pca = prcomp(dim_rel_scaled)
ncomp = 6

loadings_none = dim_rel.pca$rotation[,1:ncomp]%*% diag(dim_rel.pca$sdev,ncomp,ncomp)
scores_none = dim_rel.pca$x[,1:ncomp] 

loadings_var = varimax(loadings_none)$loadings
scores_var = scale(scores_none) %*% varimax(loadings_none)$rotmat

write.csv(loadings_var,'output_data/pca_results/triadic_loadings_var_all_6c.csv')
write.csv(scores_var,'output_data/pca_results/triadic_scores_var_all_6c.csv')

# %%
loadings_var_reorder = as.data.frame(loadings_var[,1:ncomp])

#filter each row's max loading, and attribute it to correspnding column.
order_list = c()
for (row in c(1:33)){
    temp_max = abs(loadings_var_reorder[row,1])
    n = 1
    for (col in c(2:6)){
        temp = abs(loadings_var_reorder[row,col])
        if (temp > temp_max){
            temp_max = temp
            n = col
        }
        
    }
    order_list[row] = n
}
loadings_var_reorder = loadings_var_reorder %>% mutate(order = order_list)
RC1 = loadings_var_reorder %>% filter(order==1) %>% arrange(desc(V1))
RC2 = loadings_var_reorder %>% filter(order==2) %>% arrange(desc(V2))
RC3 = loadings_var_reorder %>% filter(order==3) %>% arrange(desc(V3))
RC4 = loadings_var_reorder %>% filter(order==4) %>% arrange(desc(V4))
RC5 = loadings_var_reorder %>% filter(order==5) %>% arrange(desc(V5))
RC6 = loadings_var_reorder %>% filter(order==6) %>% arrange(desc(V6))

loadings_var_reorder = rbind(RC1,RC2,RC3,RC4,RC5,RC6)
loadings_var_reorder = loadings_var_reorder[1:6]
colnames(loadings_var_reorder) = c('Exchange','Formality','Equality','Activeness','Valence','?')

options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 0.3,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

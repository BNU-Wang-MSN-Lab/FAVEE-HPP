# %%
library(FactoMineR)
library(factoextra)#fviz_eig
library(psych)

library(ggplot2)
library(corrplot)
library(RColorBrewer)

library(tidyverse)
library(reshape)#melt
library(nFactors)#optimal number of components

library(mgsub)
library(openxlsx)
library(ggrepel)

# %%
loadings_var_reorder = read.csv('level_results/15regions_2385r/Forbes_level2.csv',row.names=1)
options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 1.4,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %%
loadings_var_reorder = read.csv('level_results/15regions_2385r/Forbes_level3.csv',row.names=1)
options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 1,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %%
loadings_var_reorder = read.csv('level_results/15regions_2385r/Forbes_level4.csv',row.names=1)
options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 0.6,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %%
loadings_var_reorder = read.csv('level_results/15regions_2385r/Forbes_level5.csv',row.names=1)
options(repr.plot.width=6, repr.plot.height=10)
my.breaks = c(seq(-1,1,by=0.01))
corrplot(as.matrix(loadings_var_reorder),is.corr=FALSE,
         tl.col = "black",tl.srt=60,tl.cex=1.1,family='sans',font=2,
         col.lim = c(-1,1),cl.ratio = 0.4,cl.cex=1,
         col = colorRampPalette(rev(brewer.pal(n=7,name ="RdBu")))(length(my.breaks)))
# Out:
# Plot with title ""

# %%
loadings_var_reorder = read.csv('level_results/15regions_2385r/Forbes_level5.csv',row.names=1)
loadings_var_reorder
# Out:
#                            Activeness  Formality    Exchange     Valence
# Importance.for.individuals  0.77134321  0.146821328 -0.096112565 -0.0218301470
# Importance.for.society      0.69218059 -0.305216965  0.032009885 -0.1597894683
# Activeness                  0.65199995  0.094952428  0.124148904  0.0538188068
# Trust                       0.63068964  0.133685008  0.047234559  0.4361467738
# Spatial.Distance            0.61155548  0.175185162  0.122457953  0.0170144651
# Synchronicity               0.60738631 -0.032132260  0.098596366 -0.0040438074
# Affiliation.Coalition       0.60428179  0.060342322  0.073166928  0.3110321264
# Information.Exchange        0.59881223 -0.005587406  0.200715558  0.1989551448
# Morality                    0.59289856 -0.191558673 -0.220463815  0.3871158332
# Endurance                   0.59107919  0.375159022 -0.170611938  0.0037632807
# Activity.Intensity          0.52529398  0.412088903  0.003149190 -0.0018636342
# Formality.and.Regulation    0.18075178 -0.746901798  0.204680542 -0.0633946232
# Intimacy                    0.14639591  0.689188938  0.116281551  0.0575765348
# Mating                      0.06480926  0.665701272  0.237033507 -0.1403155556
# Love.Expression             0.35686960  0.664811363 -0.071207613  0.0660603464
# Socioemotional              0.14862345  0.663167092 -0.156136003  0.0866412979
# Occupational                0.34541591 -0.663161591  0.346330263 -0.0265743064
# Attachment                  0.42134505  0.616503320  0.007648191  0.1179768880
# Strategic                  -0.01877147 -0.603444710  0.326488890 -0.2525299156
# Uniqueness                  0.39158685  0.592757233 -0.067877730 -0.1877460255
# Visibility                  0.32925068 -0.586375105 -0.131390945  0.0474552815
# Communal.Sharing            0.34101969  0.460326419 -0.197750648  0.1492718342
# Money.Exchange             -0.08992133  0.033924304  0.873570998 -0.0458843631
# Service.Exchange            0.07112807 -0.108348449  0.767930611  0.2021427216
# Concreteness                0.01938124 -0.241038659  0.587833631 -0.0394774457
# Goods.Exchange             -0.12416537  0.136895887  0.583717873 -0.0191409319
# Negotiation                 0.15332825 -0.060591672  0.530867094 -0.1600797544
# Conflict                    0.04778119 -0.046535148 -0.062351930 -0.9482364980
# Coercion                    0.06381698  0.110917954  0.143782643 -0.7891126086
# Valence.Evaluation          0.31545708  0.150765006  0.216247352  0.5854087624
# Equality                   -0.04503857  0.053309059 -0.081663139  0.0006246817
# Expected.Reciprocity        0.13919127 -0.062625858  0.304732031  0.1613241477
# Generation.Gap              0.26927426  0.036277343  0.077801395  0.0995135086
#                            Equality
# Importance.for.individuals  0.02440434
# Importance.for.society     -0.07313840
# Activeness                  0.11289742
# Trust                      -0.01267797
# Spatial.Distance           -0.05112037
# Synchronicity               0.12360366
# Affiliation.Coalition       0.13205566
# Information.Exchange        0.07061134
# Morality                    0.02931894
# Endurance                  -0.01587106
# Activity.Intensity          0.19083382
# Formality.and.Regulation   -0.08910157
# Intimacy                    0.15527107
# Mating                      0.09080289
# Love.Expression             0.06853858
# Socioemotional              0.22530807
# Occupational               -0.11212826
# Attachment                  0.03145167
# Strategic                   0.13521957
# Uniqueness                 -0.02153326
# Visibility                  0.12482192
# Communal.Sharing            0.24188329
# Money.Exchange             -0.03282431
# Service.Exchange           -0.19412175
# Concreteness                0.12584854
# Goods.Exchange              0.06475991
# Negotiation                 0.28208344
# Conflict                    0.08051690
# Coercion                   -0.17258436
# Valence.Evaluation          0.14280019
# Equality                    0.86567036
# Expected.Reciprocity        0.58572742
# Generation.Gap             -0.54927058

# %%
write.csv(loadings_var_reorder,'level5_loadings_order.csv')

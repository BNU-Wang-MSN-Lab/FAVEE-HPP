# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/prejudice_ECD'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.2444 -0.7582 -0.1071  0.6485  1.9509
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -8.461e-17  6.838e-02   0.000        1
# scale(x)     4.530e-01  6.858e-02   6.605 4.94e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8942 on 169 degrees of freedom
# Multiple R-squared:  0.2052,	Adjusted R-squared:  0.2005
# F-statistic: 43.63 on 1 and 169 DF,  p-value: 4.944e-10
#
# [1] "fstats: 43.6300864148523"
# [1] "r2stats: 0.205192440780595"
# [1] 10000
# [1] "permf_pvals 8e-04"
#   full_rdm
# 1    8e-04
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9768 -0.7525 -0.1309  0.7487  2.0825
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.332e-17  7.055e-02   0.000        1
# scale(x)     3.922e-01  7.076e-02   5.542 1.13e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9226 on 169 degrees of freedom
# Multiple R-squared:  0.1538,	Adjusted R-squared:  0.1488
# F-statistic: 30.71 on 1 and 169 DF,  p-value: 1.13e-07
#
# [1] "fstats: 30.7128774100731"
# [1] "r2stats: 0.153785163021861"
# [1] 10000
# [1] "permf_pvals 0.0038"
#   favee_rdm
# 1    0.0038
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7339 -0.6830 -0.1854  0.6655  2.4565
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -8.047e-17  6.911e-02   0.000   1.0000
# scale(x)formality_rdm  -1.976e-01  9.355e-02  -2.112   0.0362 *
# scale(x)activeness_rdm -1.519e-01  1.092e-01  -1.390   0.1663
# scale(x)valence_rdm     1.993e-01  1.114e-01   1.788   0.0756 .
# scale(x)exchange_rdm    4.330e-02  8.288e-02   0.522   0.6021
# scale(x)equality_rdm    4.674e-01  1.048e-01   4.462  1.5e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9037 on 165 degrees of freedom
# Multiple R-squared:  0.2074,	Adjusted R-squared:  0.1833
# F-statistic: 8.633 on 5 and 165 DF,  p-value: 2.747e-07
#
# [1] "fstats: 8.63331205600518"
# [1] "r2stats: 0.20736548762663"
# [1] 10000
# [1] "permf_pvals 0.011"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1         0.895         0.8061      0.1723       0.3695        0.003
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5214 -0.8130 -0.1608  0.6685  2.6598
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.252e-17  7.614e-02   0.000    1.000
# scale(x)    1.206e-01  7.636e-02   1.579    0.116
#
# Residual standard error: 0.9956 on 169 degrees of freedom
# Multiple R-squared:  0.01454,	Adjusted R-squared:  0.008705
# F-statistic: 2.493 on 1 and 169 DF,  p-value: 0.1162
#
# [1] "fstats: 2.49281068744591"
# [1] "r2stats: 0.0145359486351249"
# [1] 10000
# [1] "permf_pvals 0.353"
#   formality_rdm
# 1        0.1735
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7218 -0.8112 -0.1406  0.6774  2.7016
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.065e-16  7.521e-02   0.000   1.0000
# scale(x)     1.959e-01  7.543e-02   2.597   0.0102 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9835 on 169 degrees of freedom
# Multiple R-squared:  0.03839,	Adjusted R-squared:  0.0327
# F-statistic: 6.746 on 1 and 169 DF,  p-value: 0.01022
#
# [1] "fstats: 6.74642473865474"
# [1] "r2stats: 0.0383872659070423"
# [1] 10000
# [1] "permf_pvals 0.0948"
#   activeness_rdm
# 1         0.0549
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8440 -0.7634 -0.2067  0.7407  2.3294
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.026e-17  7.301e-02   0.000        1
# scale(x)     3.065e-01  7.322e-02   4.186 4.56e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9547 on 169 degrees of freedom
# Multiple R-squared:  0.09395,	Adjusted R-squared:  0.08859
# F-statistic: 17.52 on 1 and 169 DF,  p-value: 4.557e-05
#
# [1] "fstats: 17.5232581418199"
# [1] "r2stats: 0.0939467727316684"
# [1] 10000
# [1] "permf_pvals 0.0142"
#   valence_rdm
# 1       0.014
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7093 -0.7500 -0.1782  0.6066  2.5624
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.245e-17  7.537e-02   0.000   1.0000
# scale(x)     1.855e-01  7.559e-02   2.454   0.0151 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9855 on 169 degrees of freedom
# Multiple R-squared:  0.03442,	Adjusted R-squared:  0.0287
# F-statistic: 6.024 on 1 and 169 DF,  p-value: 0.01513
#
# [1] "fstats: 6.02373554204666"
# [1] "r2stats: 0.0344166779630844"
# [1] 10000
# [1] "permf_pvals 0.1403"
#   exchange_rdm
# 1       0.0855
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6411 -0.6919 -0.1763  0.6860  2.4519
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.575e-17  6.994e-02   0.000        1
# scale(x)     4.104e-01  7.015e-02   5.851 2.48e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9146 on 169 degrees of freedom
# Multiple R-squared:  0.1684,	Adjusted R-squared:  0.1635
# F-statistic: 34.23 on 1 and 169 DF,  p-value: 2.477e-08
#
# [1] "fstats: 34.2299017046284"
# [1] "r2stats: 0.168429455594471"
# [1] 10000
# [1] "permf_pvals 0.0032"
#   equality_rdm
# 1       0.0032
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0488 -0.7521 -0.1469  0.6869  2.3967
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.611e-17  7.173e-02    0.00        1
# scale(x)     3.540e-01  7.194e-02    4.92 2.04e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.938 on 169 degrees of freedom
# Multiple R-squared:  0.1253,	Adjusted R-squared:  0.1201
# F-statistic: 24.21 on 1 and 169 DF,  p-value: 2.04e-06
#
# [1] "fstats: 24.2072922654973"
# [1] "r2stats: 0.125291814722152"
# [1] 10000
# [1] "permf_pvals 0.0017"
#   hpp_rdm
# 1  0.0017
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8426 -0.7136 -0.1694  0.6516  2.6109
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -3.944e-17  7.132e-02   0.000  1.00000
# scale(x)hostile_rdm  1.763e-01  9.383e-02   1.879  0.06193 .
# scale(x)private_rdm -1.391e-01  1.052e-01  -1.323  0.18767
# scale(x)public_rdm   3.445e-01  1.055e-01   3.266  0.00132 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9326 on 167 degrees of freedom
# Multiple R-squared:  0.1456,	Adjusted R-squared:  0.1302
# F-statistic: 9.484 on 3 and 167 DF,  p-value: 8.057e-06
#
# [1] "fstats: 9.48393646845684"
# [1] "r2stats: 0.145569434695593"
# [1] 10000
# [1] "permf_pvals 0.0096"
#   hostile_rdm private_rdm public_rdm
# 1      0.0694      0.8488     0.0207
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8578 -0.7380 -0.1117  0.6339  2.6990
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 3.561e-17  7.318e-02   0.000        1
# scale(x)    2.996e-01  7.339e-02   4.082 6.88e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9569 on 169 degrees of freedom
# Multiple R-squared:  0.08975,	Adjusted R-squared:  0.08436
# F-statistic: 16.66 on 1 and 169 DF,  p-value: 6.876e-05
#
# [1] "fstats: 16.6624381577357"
# [1] "r2stats: 0.0897458760267899"
# [1] 10000
# [1] "permf_pvals 0.0024"
#   hostile_rdm
# 1      0.0024
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7454 -0.8042 -0.1384  0.6618  2.7511
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 6.798e-17  7.504e-02   0.000   1.0000
# scale(x)    2.066e-01  7.526e-02   2.745   0.0067 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9813 on 169 degrees of freedom
# Multiple R-squared:  0.0427,	Adjusted R-squared:  0.03703
# F-statistic: 7.538 on 1 and 169 DF,  p-value: 0.006697
#
# [1] "fstats: 7.53750030086058"
# [1] "r2stats: 0.042696312613552"
# [1] 10000
# [1] "permf_pvals 0.0545"
#   private_rdm
# 1      0.0413
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0403 -0.7344 -0.1373  0.7130  2.4514
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.497e-17  7.177e-02     0.0        1
# scale(x)     3.527e-01  7.198e-02     4.9 2.24e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9385 on 169 degrees of freedom
# Multiple R-squared:  0.1244,	Adjusted R-squared:  0.1192
# F-statistic: 24.01 on 1 and 169 DF,  p-value: 2.236e-06
#
# [1] "fstats: 24.0056253746795"
# [1] "r2stats: 0.124377853381618"
# [1] 10000
# [1] "permf_pvals 0.0031"
#   public_rdm
# 1     0.0031
# [1] "###############################################################"

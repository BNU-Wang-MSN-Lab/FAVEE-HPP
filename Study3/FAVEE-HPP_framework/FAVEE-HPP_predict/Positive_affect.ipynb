# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('Qatar')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/positive_affect'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9165 -0.5908 -0.2049  0.4536  3.1076
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.835e-17  7.359e-02   0.000        1
# scale(x)    4.206e-01  7.383e-02   5.697 6.19e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9102 on 151 degrees of freedom
# Multiple R-squared:  0.1769,	Adjusted R-squared:  0.1715
# F-statistic: 32.45 on 1 and 151 DF,  p-value: 6.192e-08
#
# [1] "fstats: 32.4549407906076"
# [1] "r2stats: 0.176909603255936"
# [1] 10000
# [1] "permf_pvals 0.0416"
#   full_rdm
# 1   0.0416
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8034 -0.6131 -0.2143  0.4745  2.9688
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 9.303e-17  7.521e-02   0.000        1
# scale(x)    3.744e-01  7.546e-02   4.962 1.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9303 on 151 degrees of freedom
# Multiple R-squared:  0.1402,	Adjusted R-squared:  0.1345
# F-statistic: 24.62 on 1 and 151 DF,  p-value: 1.863e-06
#
# [1] "fstats: 24.6179118712142"
# [1] "r2stats: 0.14017882121994"
# [1] 10000
# [1] "permf_pvals 0.05"
#   favee_rdm
# 1      0.05
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7275 -0.5989 -0.1176  0.4235  2.9263
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             2.248e-17  7.334e-02   0.000   1.0000
# scale(x)formality_rdm   1.931e-01  9.530e-02   2.026   0.0446 *
# scale(x)activeness_rdm  2.680e-01  1.157e-01   2.317   0.0219 *
# scale(x)valence_rdm    -1.371e-01  1.206e-01  -1.137   0.2572
# scale(x)exchange_rdm   -5.597e-02  8.662e-02  -0.646   0.5192
# scale(x)equality_rdm    2.215e-01  1.082e-01   2.048   0.0424 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9072 on 147 degrees of freedom
# Multiple R-squared:  0.2041,	Adjusted R-squared:  0.177
# F-statistic:  7.54 on 5 and 147 DF,  p-value: 2.499e-06
#
# [1] "fstats: 7.53989977254008"
# [1] "r2stats: 0.204112621283964"
# [1] 10000
# [1] "permf_pvals 0.2111"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1          0.15         0.1221      0.6453       0.5203       0.1607
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6217 -0.6396 -0.1305  0.4962  3.0185
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.561e-17  7.571e-02   0.000        1
# scale(x)     3.587e-01  7.596e-02   4.722 5.29e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9365 on 151 degrees of freedom
# Multiple R-squared:  0.1287,	Adjusted R-squared:  0.1229
# F-statistic:  22.3 on 1 and 151 DF,  p-value: 5.286e-06
#
# [1] "fstats: 22.2992395878135"
# [1] "r2stats: 0.128674768803669"
# [1] 10000
# [1] "permf_pvals 0.0266"
#   formality_rdm
# 1        0.0263
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6131 -0.6682 -0.1687  0.5128  3.2743
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.965e-17  7.480e-02   0.000        1
# scale(x)     3.869e-01  7.504e-02   5.155 7.82e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9252 on 151 degrees of freedom
# Multiple R-squared:  0.1497,	Adjusted R-squared:  0.144
# F-statistic: 26.58 on 1 and 151 DF,  p-value: 7.824e-07
#
# [1] "fstats: 26.5767731726752"
# [1] "r2stats: 0.149663566342835"
# [1] 10000
# [1] "permf_pvals 0.0091"
#   activeness_rdm
# 1         0.0091
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5830 -0.7160 -0.1702  0.5383  3.1149
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 9.670e-17  7.751e-02   0.000  1.00000
# scale(x)    2.945e-01  7.777e-02   3.787  0.00022 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9588 on 151 degrees of freedom
# Multiple R-squared:  0.08674,	Adjusted R-squared:  0.08069
# F-statistic: 14.34 on 1 and 151 DF,  p-value: 0.0002195
#
# [1] "fstats: 14.341655104941"
# [1] "r2stats: 0.0867395157973863"
# [1] 10000
# [1] "permf_pvals 0.0887"
#   valence_rdm
# 1      0.0864
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4519 -0.7184 -0.2114  0.5337  3.2194
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 9.755e-18  7.957e-02   0.000   1.0000
# scale(x)    1.942e-01  7.983e-02   2.433   0.0162 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9842 on 151 degrees of freedom
# Multiple R-squared:  0.03772,	Adjusted R-squared:  0.03134
# F-statistic: 5.919 on 1 and 151 DF,  p-value: 0.01615
#
# [1] "fstats: 5.91857594279222"
# [1] "r2stats: 0.0377174971620311"
# [1] 10000
# [1] "permf_pvals 0.2354"
#   exchange_rdm
# 1       0.1516
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6352 -0.6453 -0.2086  0.4934  2.7739
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.595e-16  7.529e-02   0.000        1
# scale(x)    3.721e-01  7.554e-02   4.926 2.18e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9313 on 151 degrees of freedom
# Multiple R-squared:  0.1384,	Adjusted R-squared:  0.1327
# F-statistic: 24.26 on 1 and 151 DF,  p-value: 2.183e-06
#
# [1] "fstats: 24.2627985752205"
# [1] "r2stats: 0.138436672085932"
# [1] 10000
# [1] "permf_pvals 0.033"
#   equality_rdm
# 1        0.033
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5798 -0.7216 -0.2079  0.4991  3.2838
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.541e-17  7.822e-02   0.000 1.000000
# scale(x)    2.647e-01  7.848e-02   3.373 0.000944 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9675 on 151 degrees of freedom
# Multiple R-squared:  0.07008,	Adjusted R-squared:  0.06392
# F-statistic: 11.38 on 1 and 151 DF,  p-value: 0.0009437
#
# [1] "fstats: 11.3793225260179"
# [1] "r2stats: 0.0700786427052289"
# [1] 10000
# [1] "permf_pvals 0.0796"
#   hpp_rdm
# 1  0.0644
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5566 -0.5937 -0.1917  0.3520  3.0946
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -2.066e-16  7.351e-02   0.000 1.000000
# scale(x)hostile_rdm -3.453e-01  9.760e-02  -3.537 0.000539 ***
# scale(x)private_rdm  6.267e-02  1.086e-01   0.577 0.564837
# scale(x)public_rdm   5.085e-01  1.078e-01   4.716 5.48e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9093 on 149 degrees of freedom
# Multiple R-squared:  0.1895,	Adjusted R-squared:  0.1731
# F-statistic: 11.61 on 3 and 149 DF,  p-value: 6.996e-07
#
# [1] "fstats: 11.6096332073979"
# [1] "r2stats: 0.189463678963288"
# [1] 10000
# [1] "permf_pvals 0.0425"
#   hostile_rdm private_rdm public_rdm
# 1      0.9606      0.3406     0.0222
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.2535 -0.7440 -0.2326  0.4750  3.3074
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.561e-17  8.111e-02   0.000    1.000
# scale(x)    -2.694e-03  8.138e-02  -0.033    0.974
#
# Residual standard error: 1.003 on 151 degrees of freedom
# Multiple R-squared:  7.26e-06,	Adjusted R-squared:  -0.006615
# F-statistic: 0.001096 on 1 and 151 DF,  p-value: 0.9736
#
# [1] "fstats: 0.00109630848237456"
# [1] "r2stats: 7.26026836344883e-06"
# [1] 10000
# [1] "permf_pvals 0.976"
#   hostile_rdm
# 1      0.4649
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4730 -0.6946 -0.1998  0.4953  3.3328
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.109e-17  7.937e-02   0.000   1.0000
# scale(x)    2.064e-01  7.963e-02   2.592   0.0105 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9817 on 151 degrees of freedom
# Multiple R-squared:  0.04258,	Adjusted R-squared:  0.03624
# F-statistic: 6.716 on 1 and 151 DF,  p-value: 0.01049
#
# [1] "fstats: 6.71589001306743"
# [1] "r2stats: 0.0425822027984054"
# [1] 10000
# [1] "permf_pvals 0.1309"
#   private_rdm
# 1       0.094
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6885 -0.6517 -0.2304  0.4297  3.2064
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.005e-16  7.612e-02   0.000        1
# scale(x)     3.453e-01  7.637e-02   4.521 1.23e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9416 on 151 degrees of freedom
# Multiple R-squared:  0.1192,	Adjusted R-squared:  0.1134
# F-statistic: 20.44 on 1 and 151 DF,  p-value: 1.235e-05
#
# [1] "fstats: 20.4415901743141"
# [1] "r2stats: 0.119233554434079"
# [1] 10000
# [1] "permf_pvals 0.0522"
#   public_rdm
# 1      0.052
# [1] "###############################################################"

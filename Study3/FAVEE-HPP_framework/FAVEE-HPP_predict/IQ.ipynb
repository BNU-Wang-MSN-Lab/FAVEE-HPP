# %%
library(stringr)
library(ggplot2)
# Out:
# Warning message:
# "程辑包'stringr'是用R版本4.1.3 来建造的"
# Warning message:
# "程辑包'ggplot2'是用R版本4.1.3 来建造的"

# %% [markdown]
# <table><tr><td bgcolor="green">Variables</font></td></tr></table>

# %%
regions_missing = c('')
regions_order = c('USA','UK','Australia','South Africa','Germany',
                  'Japan','Israel','CHN','HK(region)','France',
                  'Spain','Mexico','Chile','Portugal','Brazil',
                  'Russia','Egypt','Qatar','India')

if (sum(regions_missing!='')>0){
    regions_order = regions_order[-which(regions_order%in%regions_missing)]
}

y_variable = 'checked/IQ'

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
fix_region = function(df){
    regions = rownames(df)
    regions = str_replace(regions,'United States','USA')
    regions = str_replace(regions,'United Kingdom','UK')
    regions = str_replace(regions,'China','CHN')
    regions = str_replace(regions,'South_africa','South Africa')
    regions = str_replace(regions,'Spain','Spanish')
    regions = str_replace(regions,'HK','HK(region)')
    regions = gsub('Hong Kong SAR, CHN','HK(region)',regions,fixed=TRUE)
    regions = str_replace(regions,'Hong Kong','HK(region)')
    regions = str_replace(regions,'Spanish','Spain')
    regions = str_replace(regions,'Russian Federation','Russia')
    regions = str_replace(regions,'Russian','Russia')
    regions = str_replace(regions,'Egypt, Arab Rep.','Egypt')
    
    rownames(df) = regions
    colnames(df) = regions
    
    df = df[regions_order,regions_order]
    return(df)
}

lowerTriangle <- function(m){
  return(m[lower.tri(m,diag = FALSE)])
}

# %%
y_rdm = read.csv(paste0('../../rdm/',y_variable,'_dist.csv'), 
                      row.names=1, encoding = "UTF-8",check.names = FALSE)
y_rdm = fix_region(y_rdm)

# %% [markdown]
# # FAVEE-HPP rdm

# %%
root_path = '../../../RSA_Regression/output_data/models_rdm/'

full_rdm = read.csv(paste0(root_path,'full_feature/raw33d_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
full_rdm = full_rdm[regions_order,regions_order]

# FAVEE
favee_rdm = read.csv(paste0(root_path,'dimensional/favee_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
favee_rdm = favee_rdm[regions_order,regions_order]

formality_rdm = read.csv(paste0(root_path,'dimensional/formality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
formality_rdm = formality_rdm[regions_order,regions_order]

activeness_rdm = read.csv(paste0(root_path,'dimensional/activeness_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
activeness_rdm = activeness_rdm[regions_order,regions_order]

valence_rdm = read.csv(paste0(root_path,'dimensional/valence_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
valence_rdm = valence_rdm[regions_order,regions_order]

exchange_rdm = read.csv(paste0(root_path,'dimensional/exchange_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
exchange_rdm = exchange_rdm[regions_order,regions_order]

equality_rdm = read.csv(paste0(root_path,'dimensional/equality_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
equality_rdm = equality_rdm[regions_order,regions_order]

# HPP
hpp_rdm = read.csv(paste0(root_path,'categorical/hpp_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hpp_rdm = hpp_rdm[regions_order,regions_order]

hostile_rdm = read.csv(paste0(root_path,'categorical/hostile_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
hostile_rdm = hostile_rdm[regions_order,regions_order]

private_rdm = read.csv(paste0(root_path,'categorical/private_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
private_rdm = private_rdm[regions_order,regions_order]

public_rdm = read.csv(paste0(root_path,'categorical/public_dissim_dist.csv'),
                    row.names =1, check.names = FALSE)
public_rdm = public_rdm[regions_order,regions_order]

# %% [markdown]
# # Predict results

# %% [markdown]
# <table><tr><td bgcolor="blue">Helper function</font></td></tr></table>

# %%
x_variables = function(variables_names){
    variables <- list()
    for(i in c(1:length(variables_names))){
      variables[[i]] = get(variables_names[i])
    }
    return(variables)
}

# %%
permutation_result = function(culture_regress_standard_model){
    # create permutation matrix
    nperm <- 10000
    permf <- matrix(NA,nperm)
    permr2 <- matrix(NA,nperm)
    # contain beta
    permt <- matrix(NA,nperm,length(variables_names)) # 12variables
    colnames(permt) <- variables_names
    # caculate proportation of beta or F value over the model results
    permf_pvals <- NA 
    permt_pvals <- NA
    tstats = NA

    # the model results
    fstats <- culture_regress_standard_model$fstatistic[[1]]
    for (i in 1:length(variables_names)){
      tstats[i] <- culture_regress_standard_model$coefficients[1+i,1]
    }
    r2stats <- culture_regress_standard_model$r.squared
    print(paste('fstats:',fstats))
    #print('tstats:')
    #tstats
    print(paste('r2stats:',r2stats))

    set.seed(2)
    for (i in 1:nperm){
      psel <- sample(length(regions_order)) # permuted index, total 17 regions
      x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x[psel,psel]))) # generate permuted predictors
      rfit <- lm(scale(y_rdm_array)~scale(x)) # fit permuted model
      srfit <- summary(rfit)
      permf[i,1] <- srfit$fstatistic[1] # F-stat
      permr2[i,1] <- srfit$r.squared # R-squared
      #permf[,i] <- unlist(lapply(srfit,function(x) x$fstatistic[1])) # F-stat
      #permr2[,i] <- unlist(lapply(srfit,function(x) x$r.squared)) # R-squared
      for (j in 1:length(variables_names)){
        permt[i,j] <- srfit$coefficients[1+j,1] # each var t-stat
      }
      #print(i)
    }
    print(i)

    # F statistics
    permf_pvals <- mean(permf[,1] >= fstats)
    print(paste('permf_pvals',permf_pvals))

    # Each variable's regression
    for (i in 1:length(variables_names)){
      permt_pvals[i] <- mean(permt[,i] >= tstats[i])
    }

    permt_pvals <- as.data.frame(t(permt_pvals)) 

    colnames(permt_pvals) <- variables_names
    return(permt_pvals)
}

# %% [markdown]
# ***

# %%
variables_names_list <- list()
variables_names_list[['full_rdm']] <- 'full_rdm'


variables_names_list[['favee_rdm']] <- 'favee_rdm'
variables_names_list[['favee_separate']] <- c('formality_rdm','activeness_rdm','valence_rdm',
                                              'exchange_rdm','equality_rdm')
variables_names_list[['formality_rdm']] <- 'formality_rdm'
variables_names_list[['activeness_rdm']] <- 'activeness_rdm'
variables_names_list[['valence_rdm']] <- 'valence_rdm'
variables_names_list[['exchange_rdm']] <- 'exchange_rdm'
variables_names_list[['equality_rdm']] <- 'equality_rdm'


variables_names_list[['hpp_rdm']] <- 'hpp_rdm'
variables_names_list[['hpp_separate']] <- c('hostile_rdm','private_rdm','public_rdm')
variables_names_list[['hostile_rdm']] <- 'hostile_rdm'
variables_names_list[['private_rdm']] <- 'private_rdm'
variables_names_list[['public_rdm']] <- 'public_rdm'

# %%
y_rdm_array = lowerTriangle(y_rdm)
for (variables_label in names(variables_names_list)){
    print(variables_label)
    variables_names = variables_names_list[[variables_label]]
    variables = x_variables(variables_names=variables_names)
    
    x <- do.call(cbind,lapply(variables,function(x) lowerTriangle(x)))
    colnames(x) = variables_names
    culture_regress_standard <- lm(scale(y_rdm_array)~scale(x))
    culture_regress_standard_model <- summary(culture_regress_standard)
    print(culture_regress_standard_model)                          
                              
    p_value = permutation_result(culture_regress_standard_model)
    print(p_value)
    print('###############################################################')
}
# Out:
# [1] "full_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0544 -0.6930 -0.1767  0.5410  3.0614
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.889e-17  7.368e-02   0.000 1.000000
# scale(x)     2.779e-01  7.389e-02   3.761 0.000233 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9634 on 169 degrees of freedom
# Multiple R-squared:  0.07724,	Adjusted R-squared:  0.07178
# F-statistic: 14.15 on 1 and 169 DF,  p-value: 0.0002329
#
# [1] "fstats: 14.1458365351281"
# [1] "r2stats: 0.0772381005364264"
# [1] 10000
# [1] "permf_pvals 0.056"
#   full_rdm
# 1   0.0511
# [1] "###############################################################"
# [1] "favee_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8336 -0.7222 -0.2497  0.5529  3.0966
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.423e-17  7.493e-02    0.00  1.00000
# scale(x)     2.134e-01  7.515e-02    2.84  0.00507 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9798 on 169 degrees of freedom
# Multiple R-squared:  0.04554,	Adjusted R-squared:  0.0399
# F-statistic: 8.064 on 1 and 169 DF,  p-value: 0.00507
#
# [1] "fstats: 8.06408214038165"
# [1] "r2stats: 0.0455432973356404"
# [1] 10000
# [1] "permf_pvals 0.1526"
#   favee_rdm
# 1    0.0972
# [1] "###############################################################"
# [1] "favee_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6554 -0.6967 -0.2195  0.6446  2.7506
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -2.840e-16  7.155e-02   0.000  1.00000
# scale(x)formality_rdm  -2.749e-01  9.686e-02  -2.839  0.00510 **
# scale(x)activeness_rdm  3.714e-01  1.131e-01   3.284  0.00125 **
# scale(x)valence_rdm     2.069e-02  1.154e-01   0.179  0.85791
# scale(x)exchange_rdm   -3.430e-02  8.580e-02  -0.400  0.68985
# scale(x)equality_rdm    1.655e-01  1.085e-01   1.526  0.12901
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9356 on 165 degrees of freedom
# Multiple R-squared:  0.1504,	Adjusted R-squared:  0.1246
# F-statistic: 5.841 on 5 and 165 DF,  p-value: 5.379e-05
#
# [1] "fstats: 5.84117816097364"
# [1] "r2stats: 0.150386225071892"
# [1] 10000
# [1] "permf_pvals 0.1318"
#   formality_rdm activeness_rdm valence_rdm exchange_rdm equality_rdm
# 1        0.9674         0.0171      0.4169       0.5236       0.1978
# [1] "###############################################################"
# [1] "formality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.4309 -0.8132 -0.2324  0.6314  2.9213
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.091e-17  7.666e-02   0.000    1.000
# scale(x)     3.252e-02  7.688e-02   0.423    0.673
#
# Residual standard error: 1.002 on 169 degrees of freedom
# Multiple R-squared:  0.001058,	Adjusted R-squared:  -0.004853
# F-statistic: 0.179 on 1 and 169 DF,  p-value: 0.6728
#
# [1] "fstats: 0.178968427467235"
# [1] "r2stats: 0.00105786451549363"
# [1] 10000
# [1] "permf_pvals 0.8213"
#   formality_rdm
# 1        0.3831
# [1] "###############################################################"
# [1] "activeness_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8296 -0.6588 -0.2126  0.5659  2.9478
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.897e-16  7.272e-02   0.000        1
# scale(x)     3.178e-01  7.294e-02   4.357 2.28e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.951 on 169 degrees of freedom
# Multiple R-squared:  0.101,	Adjusted R-squared:  0.09567
# F-statistic: 18.98 on 1 and 169 DF,  p-value: 2.28e-05
#
# [1] "fstats: 18.984887723631"
# [1] "r2stats: 0.100991563489624"
# [1] 10000
# [1] "permf_pvals 0.0118"
#   activeness_rdm
# 1         0.0111
# [1] "###############################################################"
# [1] "valence_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7510 -0.7509 -0.2011  0.5692  3.0651
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.023e-17  7.460e-02   0.000  1.00000
# scale(x)     2.323e-01  7.482e-02   3.105  0.00223 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9755 on 169 degrees of freedom
# Multiple R-squared:  0.05396,	Adjusted R-squared:  0.04836
# F-statistic:  9.64 on 1 and 169 DF,  p-value: 0.002233
#
# [1] "fstats: 9.63985363554927"
# [1] "r2stats: 0.0539625029878044"
# [1] 10000
# [1] "permf_pvals 0.1037"
#   valence_rdm
# 1      0.0741
# [1] "###############################################################"
# [1] "exchange_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5032 -0.7770 -0.2187  0.6508  2.9766
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.266e-17  7.638e-02   0.000    1.000
# scale(x)     9.136e-02  7.660e-02   1.193    0.235
#
# Residual standard error: 0.9988 on 169 degrees of freedom
# Multiple R-squared:  0.008347,	Adjusted R-squared:  0.00248
# F-statistic: 1.423 on 1 and 169 DF,  p-value: 0.2346
#
# [1] "fstats: 1.42259146421147"
# [1] "r2stats: 0.00834743476195882"
# [1] 10000
# [1] "permf_pvals 0.5223"
#   exchange_rdm
# 1       0.2343
# [1] "###############################################################"
# [1] "equality_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6699 -0.7417 -0.2230  0.6419  3.0650
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.951e-17  7.447e-02   0.000  1.00000
# scale(x)     2.395e-01  7.468e-02   3.207  0.00161 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9738 on 169 degrees of freedom
# Multiple R-squared:  0.05736,	Adjusted R-squared:  0.05178
# F-statistic: 10.28 on 1 and 169 DF,  p-value: 0.001605
#
# [1] "fstats: 10.2839382142432"
# [1] "r2stats: 0.0573611797948903"
# [1] 10000
# [1] "permf_pvals 0.0767"
#   equality_rdm
# 1       0.0597
# [1] "###############################################################"
# [1] "hpp_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9947 -0.7239 -0.1617  0.5804  2.8807
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.202e-17  7.443e-02    0.00  1.00000
# scale(x)     2.411e-01  7.465e-02    3.23  0.00149 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9734 on 169 degrees of freedom
# Multiple R-squared:  0.05815,	Adjusted R-squared:  0.05258
# F-statistic: 10.43 on 1 and 169 DF,  p-value: 0.001487
#
# [1] "fstats: 10.4339975151128"
# [1] "r2stats: 0.0581495015415573"
# [1] 10000
# [1] "permf_pvals 0.0629"
#   hpp_rdm
# 1  0.0511
# [1] "###############################################################"
# [1] "hpp_separate"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1414 -0.7291 -0.1475  0.5931  3.0139
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -3.081e-17  7.394e-02   0.000  1.00000
# scale(x)hostile_rdm -1.185e-01  9.728e-02  -1.219  0.22473
# scale(x)private_rdm  4.119e-02  1.090e-01   0.378  0.70610
# scale(x)public_rdm   3.131e-01  1.094e-01   2.863  0.00474 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9669 on 167 degrees of freedom
# Multiple R-squared:  0.08158,	Adjusted R-squared:  0.06509
# F-statistic: 4.945 on 3 and 167 DF,  p-value: 0.002578
#
# [1] "fstats: 4.94493001188937"
# [1] "r2stats: 0.081583892899473"
# [1] 10000
# [1] "permf_pvals 0.0995"
#   hostile_rdm private_rdm public_rdm
# 1      0.8197      0.3663     0.0495
# [1] "###############################################################"
# [1] "hostile_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.5036 -0.7737 -0.2073  0.6206  2.7987
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.904e-18  7.636e-02   0.000    1.000
# scale(x)     9.319e-02  7.659e-02   1.217    0.225
#
# Residual standard error: 0.9986 on 169 degrees of freedom
# Multiple R-squared:  0.008684,	Adjusted R-squared:  0.002818
# F-statistic:  1.48 on 1 and 169 DF,  p-value: 0.2254
#
# [1] "fstats: 1.48049529640396"
# [1] "r2stats: 0.00868425032335759"
# [1] 10000
# [1] "permf_pvals 0.3111"
#   hostile_rdm
# 1       0.153
# [1] "###############################################################"
# [1] "private_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.9262 -0.7242 -0.2113  0.5925  2.9467
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.537e-17  7.531e-02   0.000    1.000
# scale(x)    1.895e-01  7.553e-02   2.509    0.013 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9848 on 169 degrees of freedom
# Multiple R-squared:  0.03592,	Adjusted R-squared:  0.03021
# F-statistic: 6.297 on 1 and 169 DF,  p-value: 0.01304
#
# [1] "fstats: 6.29650050533523"
# [1] "r2stats: 0.0359191454888376"
# [1] 10000
# [1] "permf_pvals 0.1026"
#   private_rdm
# 1      0.0708
# [1] "###############################################################"
# [1] "public_rdm"
#
# Call:
# lm(formula = scale(y_rdm_array) ~ scale(x))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0655 -0.7183 -0.1554  0.6313  2.8954
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.848e-17  7.383e-02   0.000 1.000000
# scale(x)     2.710e-01  7.405e-02   3.659 0.000338 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.9654 on 169 degrees of freedom
# Multiple R-squared:  0.07342,	Adjusted R-squared:  0.06793
# F-statistic: 13.39 on 1 and 169 DF,  p-value: 0.0003377
#
# [1] "fstats: 13.3907091108928"
# [1] "r2stats: 0.0734177150588923"
# [1] 10000
# [1] "permf_pvals 0.0522"
#   public_rdm
# 1     0.0466
# [1] "###############################################################"
